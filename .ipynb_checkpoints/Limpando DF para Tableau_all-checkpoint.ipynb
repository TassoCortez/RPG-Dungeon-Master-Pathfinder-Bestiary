# %%
import pandas as pd
import regex as re
pd.set_option('display.max_columns', 500)
import os
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.keys import Keys
import regex as re

# %% [markdown]
# # Obs
# DF inicial tem 288 linhas e 30 col

# %%
df_tableau_b1 = pd.read_csv('df_b1_tableau.csv',sep='#')

# %%
list_arq_b1 = os.listdir('img_name_b1') # pegando o nome de todos os arquivos da pasta em questão. 

list_img_b1 = [file.replace('_','/').replace('.jpg','') for file in list_arq_b1 if file.endswith('.jpg')] # tranfomando os os nomes dos arquivos, apenas os que acabam com .jpg em uma lista.

# %%
def apenas_num (argumento):
    ''' Pega apenas os numeros '''
    try:
        so_num = re.findall('[0-9]?[0-9]?[0-9]',argumento)
        return int(so_num[0]) 
        
    except:
         return argumento

# %%
df_tableau_b1['CR'] = df_tableau_b1['CR'].apply(apenas_num)
df_tableau_b1['HP'] = df_tableau_b1['HP'].apply(apenas_num)
df_tableau_b1['CMD'] = df_tableau_b1['CMD'].apply(apenas_num)

# %%
def apenas_num_pos_neg (argumento):
    ''' Pega apenas os numeros com o sinal '''
    try:
        so_num = re.findall('[+][0-9]?[0-9]?[0-9]|[–][0-9]?[0-9]?[0-9]',argumento)
        return so_num 
        
    except:
         return argumento

# %%
df_tableau_b1['CMB'] = df_tableau_b1['CMB'].apply(apenas_num_pos_neg)
df_tableau_b1['Perc'] = df_tableau_b1['Perc'].apply(apenas_num_pos_neg)
df_tableau_b1['Inic'] = df_tableau_b1['Inic'].apply(apenas_num_pos_neg)

# %%
#  df_tableau_b1.to_csv('df_b1_limpo_tableau.csv', sep='#' , index = False) # salvando o DF em um arquivo com o ± como separador

# %%
df_tableau_b1
# Out:
#                Nome_limpo                  Img_nome  \
# 0                AASIMAR             AASIMAR CR 1/2
# 1                ABOLETH               ABOLETh CR 7
# 2        ANIMATED OBJECT       AnIMATED OBjECT CR 3
# 3                 ANKHEG                AnkhEg CR 3
# 4           ANKYLOSAURUS          AnkyLOSAURUS CR 6
# ..                    ...                       ...
# 269                 XILL                  XILL CR 6
# 270                 XORN                  XORN CR 6
# 271  YELLOW MUSK CREEPER   yELLOW MUSk CREEPER CR 2
# 272           YETH HOUND            yETh hOUnD CR 3
# 273                 YETI                  YETI CR 4
#
#                                                   Name CR Alm      Size  HP  \
# 0    This supernaturally beautiful woman looks huma...  1  NG    Medium  11
# 1                                              Aboleth  7  LE      Huge  84
# 2                                             Subpages  1  L   Colossal  []
# 3                                               Ankheg  3  N      Large  28
# 4    Thick bony plates armor the domelike back of t...  6  N       Huge  75
# ..                                                 ... ..  ..       ...  ..
# 269                                               Xill  6  LE    Medium  67
# 270                                               Xorn  6  N     Medium  66
# 271  Coiling around several human skeletons, this w...  2  N     Medium  22
# 272                                         Yeth Hound  3  NE    Medium  30
# 273                                               Yeti  4  N      Large  45
#
#                                                    Atk  \
# 0                      ['Melee heavy mace –1 (1d8–1)']
# 1         ['Melee 4 tentacles +10 (1d6+5 plus slime)']
# 2                                                   []
# 3     ['Melee bite +5 (2d6+4 plus 1d4 acid and grab)']
# 4                ['Melee tail +14 (3d6+12 plus stun)']
# ..                                                 ...
# 269  ['Melee short swords +13/+13/+8 (1d6+3/19–20),...
# 270    ['Melee bite +10 (4d6+3), 3 claws +10 (1d4+3)']
# 271                       ['Melee tendril +5 (1d4+4)']
# 272  ['Melee bite +7 (2d6+4 plus sinister bite and ...
# 273         ['Melee 2 claws +9 (1d6+4 plus 1d6 cold)']
#
#                                                    Def                    DR  \
# 0       ['AC 15, touch 10, flat-footed 15 (+5 armor)']                    []
# 1    ['AC 20, touch 9, flat-footed 19; (+1 Dex, +11...                    []
# 2                                                   []                    []
# 3    ['AC 16, touch 9, flat-footed 16 (+7 natural, ...                    []
# 4    ['AC 22, touch 8, flat-footed 22 (+14 natural,...                    []
# ..                                                 ...                   ...
# 269  ['AC 21, touch 14, flat-footed 17 (+4 Dex, +5 ...                    []
# 270  ['AC 21, touch 10, flat-footed 21 (+11 natural)']  ['DR 5/bludgeoning']
# 271  ['AC 14, touch 12, flat-footed 12 (+2 Dex, +2 ...                    []
# 272  ['AC 15, touch 12, flat-footed 13 (+2 Dex, +3 ...       ['DR 5/silver']
# 273  ['AC 17, touch 10, flat-footed 16 (+1 Dex, +7 ...                    []
#
#                              Saves                            Immune Res  \
# 0     ['Fort +4, Ref +0, Will +5']                                []  []
# 1    ['Fort +8, Ref +5, Will +11']                                []  []
# 2                               []                                []  []
# 3     ['Fort +6, Ref +3, Will +2']                                []  []
# 4    ['Fort +12, Ref +7, Will +4']                                []  []
# ..                             ...                               ...  ..
# 269  ['Fort +8, Ref +10, Will +6']                                []  []
# 270   ['Fort +8, Ref +2, Will +5']  ['Immune cold, fire, flanking;']  []
# 271   ['Fort +6, Ref +3, Will +1']                                []  []
# 272   ['Fort +3, Ref +6, Will +6']                                []  []
# 273   ['Fort +6, Ref +6, Will +6']                                []  []
#
#             SR                                   Spl.Like.Abl  \
# 0           []  [' Abilities (CL 1st)\n1/day–daylight\n', '']
# 1           []                                           ['']
# 2           []                                             []
# 3           []                                           ['']
# 4           []                                           ['']
# ..         ...                                            ...
# 269  ['SR 17']                                           ['']
# 270         []                                           ['']
# 271         []                                           ['']
# 272         []                                           ['']
# 273         []                                           ['']
#
#                                                 Spells lvl_9 lvl_8 lvl_7  \
# 0                         ['Spells Prepared (CL 1st)']    []    []    []
# 1                                                   []    []    []    []
# 2    ['Spells animate objects, permanency; Skill op...    []    []    []
# 3                                                   []    []    []    []
# 4                                                   []    []    []    []
# ..                                                 ...   ...   ...   ...
# 269                                                 []    []    []    []
# 270                                                 []    []    []    []
# 271                                                 []    []    []    []
# 272                                                 []    []    []    []
# 273                                                 []    []    []    []
#
#         lvl_6 lvl_5 lvl_4 lvl_3 lvl_2  \
# 0          []    []    []    []    []
# 1    ['6th)']    []    []    []    []
# 2          []    []    []    []    []
# 3          []    []    []    []    []
# 4          []    []    []    []    []
# ..        ...   ...   ...   ...   ...
# 269        []    []    []    []    []
# 270        []    []    []    []    []
# 271        []    []    []    []    []
# 272        []    []    []    []    []
# 273        []    []    []    []    []
#
#                                                  lvl_1  Inic  \
# 0    ['1st)', '1st)', '1st–bless, command (DC 14), ...  [+0]
# 1                                                   []  [+5]
# 2                                                   []    []
# 3                                                   []  [+0]
# 4                                                   []  [+0]
# ..                                                 ...   ...
# 269                                                 []  [+8]
# 270                                                 []  [+0]
# 271                                                 []  [+2]
# 272                                                 []  [+6]
# 273                                                 []  [+1]
#
#                                               Spd  Perc  \
# 0              ['Speed 30 ft. (20 ft. in armor)']  [+5]
# 1                   ['Speed 10 ft., swim 60 ft.']  [+1]
# 2                                              []    []
# 3                 ['Speed 30 ft., burrow 20 ft.']  [+8]
# 4                                ['Speed 30 ft.']  [+1]
# ..                                            ...   ...
# 269                              ['Speed 40 ft.']  [+1]
# 270  ['Speed 20 ft., burrow 20 ft.; earth glide']  [+1]
# 271                               ['Speed 5 ft.']  [+0]
# 272           ['Speed 40 ft., fly 60 ft. (good)']  [+9]
# 273                ['Speed 40 ft., climb 30 ft.']  [+1]
#
#                                                 Senses    CMB CMD  \
# 0                        ['Senses darkvision 60 ft.;']   [–1]   9
# 1                        ['Senses darkvision 60 ft.;']  [+13]  24
# 2                                                   []     []  []
# 3    ['Senses darkvision 60 ft., low-light vision, ...   [+7]  17
# 4                  ['Senses low-light vision, scent;']  [+17]  27
# ..                                                 ...    ...  ..
# 269                      ['Senses darkvision 60 ft.;']  [+12]  26
# 270  ['Senses all-around vision, darkvision 60 ft.,...  [+10]  20
# 271                     ['Senses tremorsense 30 ft.;']   [+5]  17
# 272               ['Senses darkvision 60 ft., scent;']   [+7]  19
# 273               ['Senses darkvision 60 ft., scent;']  [+11]  22
#
#                XP
# 0      ['XP 200']
# 1    ['XP 3,200']
# 2              []
# 3      ['XP 800']
# 4    ['XP 2,400']
# ..            ...
# 269  ['XP 2,400']
# 270  ['XP 2,400']
# 271    ['XP 600']
# 272    ['XP 800']
# 273  ['XP 1,200']
#
# [274 rows x 32 columns]
