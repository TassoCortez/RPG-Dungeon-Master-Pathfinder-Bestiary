# %%
import PIL
import fitz
import pandas as pd 
from PIL import Image
import io
import re

# %%
doc = fitz.open('Data/Pathfinder_Bestiary_3.pdf') # abrindo o PDF

# %% [markdown]
# obs:

# %% [markdown]
# # Tratamenteo para pegar imagem

# %%
def req_image (argumento):
    '''recebe um int(numero da pagina), substitue este valor e extrai a imagem da pg em questão'''
    page_image = doc[argumento] # salvando a pagina [numero da pagina] como page
    
    list_image = page_image.get_images() #  lista de imagens da pagina escolhida

    for item in list_image: 
            if item[3] >100 and item[3] != 1669 and item[2] >150 and item[3] != 1636 :   # escolha da imagem pelo tamanho, quarto parametro acima de 100 e diferente de 1603, oitvo parametro da imagem igual a DCTDecode 
                img_creature = item
            else:
                ''
    imagem_isolada = doc.extract_image(img_creature[0])['image']
    
    return imagem_isolada

# %% [markdown]
# # Tratamento para pegar nome do monstro

# %%
def req_text(argument):
    
    '''Função recebe um int(numero da pagina) e retorna o nome limpo que está com a segunda coordenada de 135.28799438476562  '''
    
    page_text = doc[argument]  # salvando a pagina [numero da pagina] como page_text 

    words = page_text.get_text("words")  # extraindo todas as palavras da pagina 1
    
    lista_nomes = []
    
    for i in words:   # for para pegar o nomes do monstro na pagina. So funciona se o nome estiver com o segundo valor de 135.28799438476562
        
        for image in i:
            if image == 135.28799438476562:
                
                x = i[4]
                
                lista_nomes.append(x+' ')
            
            else:
                ''
    
    lista_nomes_sujos =''.join(lista_nomes)  
    
    
    if re.findall('.*?\d+/?\d?',lista_nomes_sujos) != []: # if para separar os nomes quando aparece algum numero
        lista_nomes_limpa = re.findall('.*?\d+/?\d?',lista_nomes_sujos)
    
    else: # else para selecionar os nomes que não tem numero
        lista_nomes_limpa = re.findall('\w*.\w*',lista_nomes_sujos)
    
    lista_nomes_limpa2 = [n.replace('/','_') for n in lista_nomes_limpa ]    
    
    return lista_nomes_limpa2

# %% [markdown]
# # Funcao para salvar a imagem com o nome certo

# %%
def img_names_b3 (pg):
    '''Funcao recebe o numero da pagina, roda a função para pegar o nome do monstro. 
    caso o nome do monstro não seja um grupo vzio, tenta rodar a função para pegar a image. Caso a função da imagem de erro, pega a imagem da proxima pagina. e salva na pasta escolhida.
    
    Caso o nome do monstro seja vazio, não tentar pegar mais nada e retorna a menssagem 'Vazio' '''   
    

    if req_text (pg) != []: # if para filtrar quando há nome na pagina
        names = (req_text (pg))    

        for item in names:   # rodando este For para pegar cada item separado quando ha mais de 1 monstro por pagina
            item = str(item)
            name_monster = item
            
        #name_monster = str(req_text(pg)[0])  # funcao req_text para pegar o nome do monstro e tranfomando o nome em str
            try:
                    imagem_pronta = PIL.Image.open(io.BytesIO(req_image(pg)))# abrindo a imagem gerada pela funcao req_image
                
                    imagem_pronta.save('C:/Users/Escanor/Desktop/Iron HAck/Projetos/Projeto obrigatorio/Pathfinder/img_name_b3/'+name_monster+'.jpg')
                
                    print ('imagem salva com o nome de :'+name_monster)
                                              
            except:
                    imagem_pronta = PIL.Image.open(io.BytesIO(req_image(pg+1)))# abrindo a imagem gerada pela funcao req_image
                
                    imagem_pronta.save('C:/Users/Escanor/Desktop/Iron HAck/Projetos/Projeto obrigatorio/Pathfinder/img_name_b3/'+name_monster+'.jpg')
                
                    return 'imagem da proxima pagina salva com o nome de :'+ name_monster

    
    elif req_text (pg) == []: # elif para filtrar quando não ha nome da pagina
        return 'vazio'
        
    
    else: # else para ajudar caso de algum erro em algum lugar estranho. 
        return 'erro'
    
    return 'image(s) Salva'

# %%
for i in range (7,290):
    img_names_b3(i)
# Out:
# imagem salva com o nome de :ADARO CR 3
# imagem salva com o nome de :ADHERER CR 3
# imagem salva com o nome de :ADLET CR 10
# imagem salva com o nome de :AHUIZOTL CR 6
# imagem salva com o nome de :AKHLUT CR 13
# imagem salva com o nome de :ALLIP CR 3
# imagem salva com o nome de :ALRAUNE CR 13
# imagem salva com o nome de :ANNIS HAG CR 6
# imagem salva com o nome de :GIANT ANT LION CR 5
# imagem salva com o nome de : GIANT ADULT ANT LION CR 6
# imagem salva com o nome de :HARBINGER ARCHON CR 2
# imagem salva com o nome de :LEGION ARCHON CR 7
# imagem salva com o nome de :ASCOMOID CR 5
# imagem salva com o nome de :ADHUKAIT CR 7
# imagem salva com o nome de :AGHASURA CR 11
# imagem salva com o nome de :TRIPURASURA CR 2
# imagem salva com o nome de :UPASUNDA CR 9
# imagem salva com o nome de :ATOMIE CR 1
# imagem salva com o nome de :AXE BEAK CR 2
# imagem salva com o nome de :AZRUVERDA CR 13
# imagem salva com o nome de :BAKU CR 8
# imagem salva com o nome de :BAREGARA CR 12
# imagem salva com o nome de :BAYKOK CR 9
# imagem salva com o nome de :TEMPEST BEHEMOTH CR 22
# imagem salva com o nome de :THALASSIC BEHEMOTH CR 20
# imagem salva com o nome de :THUNDER BEHEMOTH CR 18
# imagem salva com o nome de :BERBALANG CR 6
# imagem salva com o nome de :BHUTA CR 11
# imagem salva com o nome de :BOGEYMAN CR 10
# imagem salva com o nome de :BRAIN OOZE CR 7
# imagem salva com o nome de :CARBUNCLE CR 1
# imagem salva com o nome de :CARNIVOROUS CRYSTAL CR 11
# imagem salva com o nome de :CARYATID COLUMN CR 3
# imagem salva com o nome de :CATFOLK CR 1_2
# imagem salva com o nome de :CAULBORN CR 7
# imagem salva com o nome de :CECAELIA CR 5
# imagem salva com o nome de :CERATIOIDI CR 3
# imagem salva com o nome de :CERBERI CR 6
# imagem salva com o nome de :CEREBRIC FUNGUS CR 3
# imagem salva com o nome de :CLOCKWORK GOLIATH CR 19
# imagem salva com o nome de :CLOCKWORK LEVIATHAN CR 12
# imagem salva com o nome de :CLOCKWORK SERVANT CR 2
# imagem salva com o nome de :CLOCKWORK SOLDIER CR 6
# imagem salva com o nome de :CLOCKWORK SPY CR 1_2
# imagem salva com o nome de :COLD RIDER CR 8
# imagem salva com o nome de :SHIPWRECKER CRAB CR 13
# imagem salva com o nome de : SHARK-EATING CRAB CR 7
# imagem salva com o nome de :GREAT CYCLOPS CR 12
# imagem salva com o nome de :CRUCIDAEMON CR 15
# imagem salva com o nome de :VULNUDAEMON CR 4
# imagem salva com o nome de :DEATHTRAP OOZE CR 8
# imagem salva com o nome de :DEATHWEB CR 6
# imagem salva com o nome de :SHAGGY DEMODAND CR 18
# imagem salva com o nome de :SLIMY DEMODAND CR 16
# imagem salva com o nome de :TARRY DEMODAND CR 13
# imagem salva com o nome de :COLOXUS CR 12
# imagem salva com o nome de :INCUBUS CR 6
# imagem salva com o nome de :SCHIR CR 4
# imagem salva com o nome de :DERHII CR 5
# imagem salva com o nome de :DIMETRODON CR 3
# imagem salva com o nome de : IGUANODON CR 6
# imagem salva com o nome de :PACHYCEPHALOSAURUS CR 4
# imagem salva com o nome de : SPINOSAURUS CR 11
# imagem salva com o nome de :DIRE CORBY CR 1
# imagem salva com o nome de :DISENCHANTER CR 3
# imagem salva com o nome de :AGHASH CR 4
# imagem salva com o nome de :DORU CR 2
# imagem salva com o nome de :GHAWWAS CR 10
# imagem salva com o nome de :PAIRAKA CR 7
# imagem salva com o nome de :SEPID CR 14
# imagem salva com o nome de :SHIRA CR 12
# imagem salva com o nome de :FAERIE DRAGON CR 2
# imagem salva com o nome de :DRAGONNE CR 7
# imagem salva com o nome de :DESERT DRAKE CR 8
# imagem salva com o nome de :RIFT DRAKE CR 9
# imagem salva com o nome de :RIVER DRAKE CR 3
# imagem salva com o nome de :DYBBUK CR 15
# imagem salva com o nome de :ECORCHE CR 16
# imagem salva com o nome de :RACCOON CR 1_2
# imagem salva com o nome de :FAUN CR 1
# imagem salva com o nome de :FESTROG CR 1
# imagem salva com o nome de :FLAIL SNAIL CR 4
# imagem salva com o nome de :FLUMPH CR 1
# imagem salva com o nome de :GARDEN OOZE CR 2
# imagem salva com o nome de :GARUDA CR 9
# imagem salva com o nome de :GHORAZAGH CR 13
# imagem salva com o nome de :GHUL CR 5
# imagem salva com o nome de :ASH GIANT CR 11
# imagem salva com o nome de :CAVE GIANT CR 6
# imagem salva com o nome de :DESERT GIANT CR 9
# imagem salva com o nome de :JUNGLE GIANT CR 10
# imagem salva com o nome de :GIRTABLILU CR 8
# imagem salva com o nome de :GLOBSTER CR 5
# imagem salva com o nome de :GOBLIN SNAKE CR 1
# imagem salva com o nome de :BONE GOLEM CR 8
# imagem salva com o nome de :BRASS GOLEM CR 14
# imagem salva com o nome de :CANNON GOLEM CR 15
# imagem salva com o nome de :FOSSIL GOLEM CR 12
# imagem salva com o nome de :GORYNYCH CR 15
# imagem salva com o nome de :FUATH CR 1
# imagem salva com o nome de :GRODAIR CR 5
# imagem salva com o nome de :GROOTSLANG CR 16
# imagem salva com o nome de :GUECUBU CR 8
# imagem salva com o nome de :HELLWASP SWARM CR 8
# imagem salva com o nome de :ANTELOPE CR 1_2
# imagem salva com o nome de : ELK CR 1
# imagem salva com o nome de :HODAG CR 6
# imagem salva com o nome de :HOLLOW SERPENT CR 16
# imagem salva com o nome de :HUECUVA CR 2
# imagem salva com o nome de :HUMBABA CR 19
# imagem salva com o nome de :HUNGRY FOG CR 6
# imagem salva com o nome de :IKU-TURSO CR 8
# imagem salva com o nome de :JACKALWERE CR 2
# imagem salva com o nome de :DEATH’S HEAD JELLYFISH CR 1
# imagem salva com o nome de : SAPPHIRE JELLYFISH CR 11
# imagem salva com o nome de :JOROGUMO CR 12
# imagem salva com o nome de :JUBJUB BIRD CR 15
# imagem salva com o nome de :KAMADAN CR 4
# imagem salva com o nome de :KODAMA CR 5
# imagem salva com o nome de :SHIKIGAMI CR 2
# imagem salva com o nome de :TOSHIGAMI CR 15
# imagem salva com o nome de :ZUISHIN CR 10
# imagem salva com o nome de :KAPPA CR 2
# imagem salva com o nome de :KECH CR 3
# imagem salva com o nome de :KIRIN CR 7
# imagem salva com o nome de :KONGAMATO CR 15
# imagem salva com o nome de :AUGUR CR 2
# imagem salva com o nome de :INTERLOCUTOR CR 12
# imagem salva com o nome de :LAMMASU CR 8
# imagem salva com o nome de :FUNGUS LESHY CR 2
# imagem salva com o nome de :GOURD LESHY CR 1
# imagem salva com o nome de :LEAF LESHY CR 1_2
# imagem salva com o nome de :SEAWEED LESHY CR 3
# imagem salva com o nome de :CAIRN LINNORM CR 18
# imagem salva com o nome de :FJORD LINNORM CR 16
# imagem salva com o nome de :TAIGA LINNORM CR 19
# imagem salva com o nome de :TOR LINNORM CR 21
# imagem salva com o nome de :GIANT GECKO CR 1
# imagem salva com o nome de : GIANT CHAMELEON CR 3
# imagem salva com o nome de :LUKWATA CR 11
# imagem salva com o nome de :MAFTET CR 6
# imagem salva com o nome de :MAGMIN CR 3
# imagem salva com o nome de :MANANANGGAL CR 7
# imagem salva com o nome de :KANGAROO CR 1_2
# imagem salva com o nome de : THYLACINE CR 1_2
# imagem salva com o nome de :ARCHELON CR 5
# imagem salva com o nome de : BALUCHITHERIUM CR 8
# imagem salva com o nome de :BASILOSAURUS CR 12
# imagem salva com o nome de : MEGALANIA CR 7
# imagem salva com o nome de :MOBOGO CR 10
# imagem salva com o nome de :MOON-BEAST CR 11
# imagem salva com o nome de :MYCELOID CR 4
# imagem salva com o nome de :LUNAR NAGA CR 6
# imagem salva com o nome de :ROYAL NAGA CR 11
# imagem salva com o nome de :WATER NAGA CR 7
# imagem salva com o nome de :NEPHILIM CR 8
# imagem salva com o nome de :NIXIE CR 1
# imagem salva com o nome de :NORN CR 18
# imagem salva com o nome de :NUCKELAVEE CR 9
# imagem salva com o nome de :NUE CR 10
# imagem salva com o nome de :FIRE YAI CR 15
# imagem salva com o nome de :ICE YAI CR 14
# imagem salva com o nome de :KUWA CR 4
# imagem salva com o nome de :SPIRIT ONI CR 2
# imagem salva com o nome de :WATER YAI CR 18
# imagem salva com o nome de :GREAT HORNED OWL CR 1_2
# imagem salva com o nome de : GIANT OWL CR 5
# imagem salva com o nome de :PALE STRANGER CR 10
# imagem salva com o nome de :ROT GRUB SWARM CR 7
# imagem salva com o nome de : GIANT ROT GRUB CR 3
# imagem salva com o nome de :PERI CR 14
# imagem salva com o nome de :PHANTOM FUNGUS CR 3
# imagem salva com o nome de :PLASMA OOZE CR 16
# imagem salva com o nome de :POPOBALA CR 15
# imagem salva com o nome de :PORCUPINE CR 1_4
# imagem salva com o nome de : GIANT PORCUPINE CR 2
# imagem salva com o nome de :PUKWUDGIE CR 7
# imagem salva com o nome de :DANDASUKA CR 5
# imagem salva com o nome de :MARAI CR 8
# imagem salva com o nome de :RAKTAVARNA CR 2
# imagem salva com o nome de :TATAKA CR 15
# imagem salva com o nome de :RATFOLK CR 1_3
# imagem salva com o nome de :RUSALKA CR 12
# imagem salva com o nome de :SABOSAN CR 5
# imagem salva com o nome de :SAGARI CR 1_2
# imagem salva com o nome de :SARGASSUM FIEND CR 9
# imagem salva com o nome de :SASQUATCH CR 2
# imagem salva com o nome de :DEADFALL SCORPION CR 8
# imagem salva com o nome de : GHOST SCORPION CR 1_2
# imagem salva com o nome de :GIANT SEA ANEMONE CR 2
# imagem salva com o nome de :SEA BONZE CR 15
# imagem salva com o nome de :DEEP SEA SERPENT CR 19
# imagem salva com o nome de :SHADOW MASTIFF CR 5
# imagem salva com o nome de :SHAE CR 4
# imagem salva com o nome de :SHEDU CR 9
# imagem salva com o nome de :SHINIGAMI CR 17
# imagem salva com o nome de :SIMURGH CR 18
# imagem salva com o nome de :SIYOKOY CR 10
# imagem salva com o nome de :SKUNK CR 1_4
# imagem salva com o nome de : GIANT SKUNK CR 3
# imagem salva com o nome de :SLEIPNIR CR 11
# imagem salva com o nome de :SNAKE SWARM CR 2
# imagem salva com o nome de : VENOMOUS SNAKE SWARM CR 4
# imagem salva com o nome de :ANDROSPHINX CR 9
# imagem salva com o nome de :CRIOSPHINX CR 7
# imagem salva com o nome de :HIERACOSPHINX CR 5
# imagem salva com o nome de :GIANT CRAB SPIDER CR 1_2
# imagem salva com o nome de : OGRE SPIDER CR 5
# imagem salva com o nome de :SPIDER EATER CR 5
# imagem salva com o nome de :SPRITE CR 1_3
# imagem salva com o nome de :STYMPHALIDIES CR 8
# imagem salva com o nome de :SULI CR 1_2
# imagem salva com o nome de :TANUKI CR 4
# imagem salva com o nome de :TAOTIEH CR 11
# imagem salva com o nome de :TATZLWYRM CR 2
# imagem salva com o nome de :TERRA-COTTA SOLDIER CR 6
# imagem salva com o nome de :THRIAE SEER CR 11
# imagem salva com o nome de :THRIAE SOLDIER CR 4
# imagem salva com o nome de :TOJANIDA CR 5
# imagem salva com o nome de :TOPHET CR 10
# imagem salva com o nome de :JOTUND TROLL CR 15
# imagem salva com o nome de :MOSS TROLL CR 3
# imagem salva com o nome de :TROLLHOUND CR 3
# imagem salva com o nome de :TUPILAQ CR 7
# imagem salva com o nome de :TZITZIMITL CR 19
# imagem salva com o nome de :VALKYRIE CR 12
# imagem salva com o nome de :VANARA CR 1_2
# imagem salva com o nome de :VISHKANYA CR 1_2
# imagem salva com o nome de :VODYANOI CR 5
# imagem salva com o nome de :VOONITH CR 4
# imagem salva com o nome de :VULTURE CR 1_2
# imagem salva com o nome de : GIANT VULTURE CR 4
# imagem salva com o nome de :WOLF-IN-SHEEP’S-CLOTHING CR 8
# imagem salva com o nome de :YITHIAN CR 9
# imagem salva com o nome de :YUKI-ONNA CR 8
# imagem salva com o nome de :ZOOG CR 1
# imagem salva com o nome de :ZUVEMBIE CR 4

# %%
#  page_text = doc[92]  # salvando a pagina [numero da pagina] como page_text 
#  words = page_text.get_text("words")
