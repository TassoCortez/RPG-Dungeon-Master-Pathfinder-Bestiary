# %%
import PIL
import fitz
import pandas as pd 
from PIL import Image
import io
import re

# %%
doc = fitz.open('Data/Pathfinder_Bestiary_5.pdf') # abrindo o PDF

# %% [markdown]
# obs:

# %% [markdown]
# # Tratamenteo para pegar imagem

# %%
def req_image (argumento):
    '''recebe um int(numero da pagina), substitue este valor e extrai a imagem da pg em questão'''
    page_image = doc[argumento] # salvando a pagina [numero da pagina] como page
    
    list_image = page_image.get_images() #  lista de imagens da pagina escolhida

    for item in list_image: 
            if item[3] >100 and item[3] != 1669 and item[2] >150 and item[3] != 1636 and item[2] != 205:   # escolha da imagem pelo tamanho, quarto parametro acima de 100 e diferente de 1603, oitvo parametro da imagem igual a DCTDecode 
                img_creature = item
            else:
                ''
    imagem_isolada = doc.extract_image(img_creature[0])['image']
    
    return imagem_isolada

# %%
req_image(95)

print('ok')
# Out:
# ok

# %%
Imagem_pronta = PIL.Image.open(io.BytesIO(req_image(95)))  # para testar se a função está funcionando.
Imagem_pronta
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=790x1023 at 0x1D983209A00>

# %%
#   
#   page_image = doc[269] # salvando a pagina [numero da pagina] como page
#   
#   list_image = page_image.get_images() #  lista de imagens da pagina escolhida
#   
#   print(list_image)
#   
#   for item in list_image: 
#           if item[3] >100 and item[3] != 1603 and item[2] >150 and item[8] == 'DCTDecode' :   # escolha da imagem pelo tamanho, quarto parametro acima de 100 e diferente de 1603, oitvo parametro da imagem igual a DCTDecode 
#               img_creature = item
#               print(item)
#           else:
#               ''
#   imagem_isolada = doc.extract_image(img_creature[0])['image']
#   
#   imagem_isolada
#   
#

# %%
page_image = doc[95] # salvando a pagina [numero da pagina] como page

list_image = page_image.get_images() #  lista de imagens da pagina escolhida

imagem_isolada = doc.extract_image(list_image[1][0])['image']

# %%
list_image
# Out:
# [(439, 438, 865, 855, 8, 'ICCBased', '', 'Im0', 'DCTDecode'),
#  (441, 440, 205, 1008, 8, 'ICCBased', '', 'Im1', 'DCTDecode'),
#  (1519, 1521, 54, 53, 8, 'ICCBased', '', 'Im2', 'FlateDecode'),
#  (1535, 1534, 54, 53, 8, 'ICCBased', '', 'Im3', 'FlateDecode'),
#  (1520, 1522, 54, 53, 8, 'ICCBased', '', 'Im4', 'FlateDecode'),
#  (1478, 0, 1277, 1669, 8, 'ICCBased', '', 'Im0', 'DCTDecode'),
#  (1480, 0, 1276, 1669, 8, 'ICCBased', '', 'Im1', 'DCTDecode')]

# %%
list_image
# Out:
# [(439, 438, 865, 855, 8, 'ICCBased', '', 'Im0', 'DCTDecode'),
#  (441, 440, 205, 1008, 8, 'ICCBased', '', 'Im1', 'DCTDecode'),
#  (1519, 1521, 54, 53, 8, 'ICCBased', '', 'Im2', 'FlateDecode'),
#  (1535, 1534, 54, 53, 8, 'ICCBased', '', 'Im3', 'FlateDecode'),
#  (1520, 1522, 54, 53, 8, 'ICCBased', '', 'Im4', 'FlateDecode'),
#  (1478, 0, 1277, 1669, 8, 'ICCBased', '', 'Im0', 'DCTDecode'),
#  (1480, 0, 1276, 1669, 8, 'ICCBased', '', 'Im1', 'DCTDecode')]

# %%
Imagem_pronta = PIL.Image.open(io.BytesIO(imagem_isolada))  # para testar se a função está funcionando.
Imagem_pronta
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=205x1008 at 0x1D995EC02B0>

# %% [markdown]
# # Tratamento para pegar nome do monstro

# %%
def req_text(argument):
    
    '''Função recebe um int(numero da pagina) e retorna o nome limpo que está com a segunda coordenada de 135.28799438476562  '''
    
    page_text = doc[argument]  # salvando a pagina [numero da pagina] como page_text 

    words = page_text.get_text("words")  # extraindo todas as palavras da pagina 1
    
    lista_nomes = []
    
    for i in words:   # for para pegar o nomes do monstro na pagina. So funciona se o nome estiver com o segundo valor de 135.28799438476562
        
        for image in i:
            if image == 135.80999755859375:
                
                x = i[4]
                
                lista_nomes.append(x+' ')
            
            else:
                ''
    
    lista_nomes_sujos =''.join(lista_nomes)  
    
    
    if re.findall('.*?\d+/?\d?',lista_nomes_sujos) != []: # if para separar os nomes quando aparece algum numero
        lista_nomes_limpa = re.findall('.*?\d+/?\d?',lista_nomes_sujos)
    
    else: # else para selecionar os nomes que não tem numero
        lista_nomes_limpa = re.findall('\w*.\w*',lista_nomes_sujos)
    
    lista_nomes_limpa2 = [n.replace('/','_') for n in lista_nomes_limpa]    
    
    lista_nomes_limpa3 = [n.replace('\t','') for n in lista_nomes_limpa2] # limpando o nome do monstro. 
    
    
    return lista_nomes_limpa3

# %%
img_name_test = [] # test para ver se os nomes estao funcionando

for i in range(7,289):
    x = req_text(i)
    img_name_test.append(x)

# %%
print (img_name_test)
# Out:
# [['AATHERIEXA CR 7'], ['LIPIKA CR 18'], [], ['OTHAOS CR 5'], ['AERIAL SERVANT CR 11'], ['CERVINAL CR 17'], ['REPTIAL CR 4'], ['AHKHAT CR 4'], ['AHOOL CR 9'], ['AKANAME CR1'], ['AMAROK CR12'], ['AMPHIPTERE CR4'], ['ANDROID CR1'], ['ANEMOS CR18'], [], ['BALISSE CR8'], ['CHORAL CR6'], ['EMPYREAN CR20'], [], ['ANIMATEHAIR CR1_2'], ['KNIGHTANT CR4', ' MEGAPONANT CR6'], ['ANUNNAKI CR18_', 'MR7'], [], ['APALLIE CR2'], ['MEGAPRIMATUS CR8'], ['APKALLU CR23_', 'MR9'], [], ['EXSCINDER CR12'], ['GATEARCHON CR17'], ['GIANTASSASSINBUG CR3', ' GREATASSASSINBUG CR5'], ['ASTOMOI CR1_2'], ['GANCANAGH CR4'], ['RAELIS CR10'], ['BAGIENNIK CR6'], ['POLARBEAR CR5', ' DIREPOLARBEAR CR8'], ['BISHAGATSUKU CR9'], ['BLIGHTSPAWN CR5'], ['BONESHIP CR18'], [], ['BRAINMOLE CR1'], ['BRAINMOLEMONARCH CR5'], ['CALLER IN DARKNESS CR 9'], ['CAMEROCERAS CR 11'], ['CAPRAMACE CR 7'], ['BLOOD CATERPILLAR CR 4', ' HORN CATERPILLAR CR 1'], ['CELEDON CR 1'], ['CERYNITIS CR 7'], ['CETUS CR 13'], ['CHERUFE CR 13'], ['CHUSPIKI CR 2'], ['CLOCKWORK FAMILIAR CR 2'], ['SPHINX COLOSSUS CR 14_', 'MR 4'], ['WOOD COLOSSUS CR 17_', 'MR 6'], ['CORPSE LOTUS CR 13'], ['CRONE QUEEN CR 15'], ['CUERO CR 5'], ['CURSED KING CR 10'], ['KABANDHA CR9'], ['CYTILLIPEDE CR6'], ['CALIGNI CR1_2'], ['DEATHCOACH CR14'], ['DEEPONE CR1'], ['ELDERDEEPONE CR14'], ['DEEPONEHYBRID CR1_2'], ['DELGETH CR6'], ['GRISTLYDEMODAND CR17'], ['STRINGYDEMODAND CR15'], ['ABRIKANDILU CR3'], ['CAMBION CR2'], ['SERAPTIS CR15'], ['DEVASTATOR CR22_', 'MR8'], ['APOSTATEDEVIL(DEIMAVIGGA) CR17'], [], ['HERESY DEVIL (AYNGAVHAUL) CR 12'], ['WARMONGER DEVIL (LEVALOCH) CR 7'], ['DIGMAUL CR 3'], ['CERATOSAURUS CR 5', ' PLESIOSAURUS CR 2'], ['TROODON CR 1', ' THERIZINOSAURUS CR 10'], ['DOPPELDREK CR 5'], [], [], ['ASTRAL DRAGON', ' '], [], ['DREAM DRAGON', ' '], [], ['ETHERIC DRAGON', ' '], [], ['NIGHTMARE DRAGON', ' '], [], ['OCCULT DRAGON', ' '], [], ['DRAGONKIN CR 9'], ['ETHER DRAKE CR 10'], ['JUNGLE DRAKE CR 6'], ['DUPPY CR 7'], ['DWIERGETH CR 13'], ['ECHENEIS CR 1'], ['EGREGORE CR 10'], [], ['AETHER ELEMENTAL', ' '], [], ['EMOTION OOZE CR 6'], [], ['ENCANTADO CR 8'], ['ETIAINEN CR 1'], [], [], ['FASTACHEE CR11'], ['FEXT CR10'], ['FIRBOLG CR4'], ['FROGFATHER CR5', ' GOLIATHFROG CR3'], ['GEGENEES CR16'], ['GHORAN CR1'], ['LENGGHOUL CR10'], ['ECLIPSEGIANT CR19'], ['MOONGIANT CR15'], ['SUNGIANT CR16'], ['GLAISTIG CR21_', 'MR10'], [], ['CRYSTALGOLEM CR11'], ['LEADGOLEM CR10'], ['GRAVEBOUND CR4'], ['GRAY CR4'], ['GRAYGOO CR14'], ['HOBKINS CR1_2'], ['NUNO CR1_4'], ['GRIEFGALL CR6'], ['GRIMREAPER CR22'], [], ['GRIMSLAKE CR6'], ['GRIOTH CR1'], ['GUARDIANSCROLL CR3'], ['GUNPOWDEROOZE CR14'], ['HAGEYEOOZE CR3'], ['HEIKEGANI CR4'], [], [], ['HUNDUN CR21'], [], ['ICHTHYOCENTAUR CR5'], ['ISONADE CR15'], ['KARKADANN CR4'], ['KAWAAKAGO CR3'], ['KETESTHIUS CR13'], ['KHALA CR17'], ['KIKIMORA CR5'], ['KUROBOZU CR6'], ['LAMHIGYN CR3'], ['LEECHROOT CR4'], ['FLYTRAPLESHY CR4'], ['LOTUSLESHY CR5'], ['LIMINALSPRITE CR2'], ['LIVINGMIRAGE CR9'], ['LOTUS TREE CR 20'], [], [], ['MANU CR 12'], [], ['RISHI MANU CR 14'], ['SOLAR PITRI', ' ', '(AGNISHVATTA', ')', ' '], [], ['TWILIGHT PITRI (BARHISAD) CR 18'], [], ['CHALICOTHERIUM CR 6', ' KAPROSUCHUS CR 5'], ['MOA CR 2', ' UINTATHERIUM CR 7'], ['DEEP MERFOLK CR 3'], ['MNGWA CR 7'], ['MOON DOG CR 9'], ['MUCKDWELLER CR 1_4', ' GIANT MUCKDWELLER CR 2'], ['MUMMY LORD CR 10'], [], ['SWAMP MUMMY CR 4'], ['MUSE CR 16'], ['MUTANT ORC CR 7'], [], ['NEMHAIN CR 15'], ['NINGEN CR 16'], ['NULMIND CR 11'], ['OPHIOTAURUS CR 17_', 'MR 7'], ['ORANG-PENDAK CR 1_2'], ['OSTOVITE CR 1'], ['PAPINIJUWARI CR 13'], ['PEUCHEN CR 10'], ['UNFETTERED PHANTOM CR 4'], ['PHARAONIC GUARDIAN CR 11'], ['PLAGUE SWARM', ' '], [], ['PLAGUED HORSE CR 2'], ['PLANKTA CR 17'], ['POLONG CR 8'], ['PSYCHEMENTAL CR 8'], ['PSYCHEPORE CR 7'], ['PUTRID OOZE CR 11'], ['PYRAUSTA CR 1_4'], ['RAMIDREJU CR 1_2'], ['REPTOID CR 1_2'], ['RHU-CHALIK CR 6'], ['RIFTCREEPER CR 15'], [], ['ANNIHILATOR CR 16'], ['GEARSMAN CR 4'], ['MYRMIDON CR11'], ['TERRAFORMER CR7'], ...

# %%
page_text = doc[7]  # salvando a pagina [numero da pagina] como page_text 
words = page_text.get_text("words")  # extraindo todas as palavras da pagina 1

# %%
words
# Out:
# [(72.0,
#   69.75652313232422,
#   163.17918395996094,
#   100.55652618408203,
#   'Aatheriexa',
#   0,
#   0,
#   0),
#  (72.0,
#   99.77200317382812,
#   77.21050262451172,
#   110.42250061035156,
#   'A',
#   0,
#   1,
#   0),
#  (81.63050079345703,
#   99.77200317382812,
#   102.62550354003906,
#   110.42250061035156,
#   'tangle',
#   0,
#   1,
#   1),
#  (107.04550170898438,
#   99.77200317382812,
#   113.20035552978516,
#   110.42250061035156,
#   'of',
#   0,
#   1,
#   2),
#  (117.62035369873047,
#   99.77200317382812,
#   133.374267578125,
#   110.42250061035156,
#   'thin,',
#   0,
#   1,
#   3),
#  (137.7942657470703,
#   99.77200317382812,
#   179.17733764648438,
#   110.42250061035156,
#   'tentacle-like',
#   0,
#   1,
#   4),
#  (183.5973358154297,
#   99.77200317382812,
#   213.56829833984375,
#   110.42250061035156,
#   'eyestalks',
#   0,
#   1,
#   5),
#  (217.98829650878906,
#   99.77200317382812,
#   237.38441467285156,
#   110.42250061035156,
#   'floats',
#   0,
#   1,
#   6),
#  (241.80441284179688,
#   99.77200317382812,
#   248.56785583496094,
#   110.42250061035156,
#   'in',
#   0,
#   1,
#   7),
#  (252.98785400390625,
#   99.77200317382812,
#   263.17083740234375,
#   110.42250061035156,
#   'the',
#   0,
#   1,
#   8),
#  (267.5908508300781,
#   99.77200317382812,
#   278.62725830078125,
#   110.42250061035156,
#   'air,',
#   0,
#   1,
#   9),
#  (283.0472717285156,
#   99.77200317382812,
#   290.9743957519531,
#   110.42250061035156,
#   'its',
#   0,
#   1,
#   10),
#  (72.0,
#   111.77401733398438,
#   114.77540588378906,
#   122.42451477050781,
#   'innumerable',
#   0,
#   2,
#   0),
#  (116.90040588378906,
#   111.77401733398438,
#   153.70199584960938,
#   122.42451477050781,
#   'unblinking',
#   0,
#   2,
#   1),
#  (155.82699584960938,
#   111.77401733398438,
#   169.40318298339844,
#   122.42451477050781,
#   'eyes',
#   0,
#   2,
#   2),
#  (171.52818298339844,
#   111.77401733398438,
#   186.6420440673828,
#   122.42451477050781,
#   'each',
#   0,
#   2,
#   3),
#  (188.7670440673828,
#   111.77401733398438,
#   221.83033752441406,
#   122.42451477050781,
#   'projecting',
#   0,
#   2,
#   4),
#  (223.95533752441406,
#   111.77401733398438,
#   232.5972900390625,
#   122.42451477050781,
#   'an',
#   0,
#   2,
#   5),
#  (234.7222900390625,
#   111.77401733398438,
#   244.12669372558594,
#   122.42451477050781,
#   'air',
#   0,
#   2,
#   6),
#  (246.25169372558594,
#   111.77401733398438,
#   252.4065399169922,
#   122.42451477050781,
#   'of',
#   0,
#   2,
#   7),
#  (254.5315399169922,
#   111.77401733398438,
#   279.50628662109375,
#   122.42451477050781,
#   'cruelty.',
#   0,
#   2,
#   8),
#  (76.0,
#   135.80999755859375,
#   125.38029479980469,
#   146.08799743652344,
#   'AATHERIEXA',
#   1,
#   0,
#   0),
#  (198.6790008544922,
#   135.80999755859375,
#   208.51600646972656,
#   146.08799743652344,
#   'CR',
#   1,
#   1,
#   0),
#  (210.92800903320312,
#   135.80999755859375,
#   216.00401306152344,
#   146.08799743652344,
#   '7',
#   1,
#   1,
#   1),
#  (72.0,
#   146.89999389648438,
#   83.46700286865234,
#   158.32000732421875,
#   'XP',
#   2,
#   0,
#   0),
#  (86.14700317382812,
#   146.89999389648438,
#   111.5739974975586,
#   158.32000732421875,
#   '3,200',
#   2,
#   0,
#   1),
#  (72.0,
#   160.80799865722656,
#   80.87520599365234,
#   169.8159942626953,
#   'NE',
#   2,
#   1,
#   0),
#  (83.08320617675781,
#   160.80799865722656,
#   111.19441223144531,
#   169.8159942626953,
#   'Medium',
#   2,
#   1,
#   1),
#  (113.40241241455078,
#   160.80799865722656,
#   148.92080688476562,
#   169.8159942626953,
#   'aberration',
#   2,
#   1,
#   2),
#  (72.0,
#   172.72000122070312,
#   84.53359985351562,
#   181.8560028076172,
#   'Init',
#   2,
#   2,
#   0),
#  (86.73600006103516,
#   172.80799865722656,
#   97.31439971923828,
#   181.8159942626953,
#   '+9;',
#   2,
#   2,
#   1),
#  (99.52239990234375,
#   172.72000122070312,
#   124.30719757080078,
#   181.8560028076172,
#   'Senses',
#   2,
#   2,
#   2),
#  (126.51200103759766,
#   172.80799865722656,
#   161.38002014160156,
#   181.8159942626953,
#   'all-around',
#   2,
#   2,
#   3),
#  (163.5880126953125,
#   172.80799865722656,
#   185.72079467773438,
#   181.8159942626953,
#   'vision,',
#   2,
#   2,
#   4),
#  (187.92880249023438,
#   172.80799865722656,
#   223.19839477539062,
#   181.8159942626953,
#   'darkvision',
#   2,
#   2,
#   5),
#  (225.40640258789062,
#   172.80799865722656,
#   237.8376007080078,
#   181.8159942626953,
#   '120',
#   2,
#   2,
#   6),
#  (240.04559326171875,
#   172.80799865722656,
#   249.6047821044922,
#   181.8159942626953,
#   'ft.,',
#   2,
#   2,
#   7),
#  (251.81277465820312,
#   172.80799865722656,
#   282.4455871582031,
#   181.8159942626953,
#   'low-light',
#   2,
#   2,
#   8),
#  (81.0,
#   184.80799865722656,
#   103.13280487060547,
#   193.8159942626953,
#   'vision,',
#   2,
#   3,
#   0),
#  (105.34080505371094,
#   184.80799865722656,
#   117.1008071899414,
#   193.8159942626953,
#   'see',
#   2,
#   3,
#   1),
#  (119.30880737304688,
#   184.80799865722656,
#   156.44798278808594,
#   193.8159942626953,
#   'invisibility;',
#   2,
#   3,
#   2),
#  (158.65597534179688,
#   184.80799865722656,
#   194.81915283203125,
#   193.8159942626953,
#   'Perception',
#   2,
#   3,
#   3),
#  (197.02716064453125,
#   184.80799865722656,
#   209.0663604736328,
#   193.8159942626953,
#   '+28',
#   2,
#   3,
#   4),
#  (71.99999237060547,
#   196.72000122070312,
#   89.02079772949219,
#   205.8560028076172,
#   'Aura',
#   2,
#   4,
#   0),
#  (91.22399139404297,
#   196.80799865722656,
#   124.15119934082031,
#   205.8159942626953,
#   'unnatural',
#   2,
#   4,
#   1),
#  (126.35919952392578,
#   196.80799865722656,
#   141.5264129638672,
#   205.8159942626953,
#   'aura',
#   2,
#   4,
#   2),
#  (143.73440551757812,
#   196.80799865722656,
#   155.07681274414062,
#   205.8159942626953,
#   '(30',
#   2,
#   4,
#   3),
#  (157.28482055664062,
#   196.80799865722656,
#   167.37840270996094,
#   205.8159942626953,
#   'ft.)',
#   2,
#   4,
#   4),
#  (72.0,
#   210.0850067138672,
#   95.30899047851562,
#   217.50799560546875,
#   'DEFENSE',
#   3,
#   0,
#   0),
#  (72.0,
#   220.72000122070312,
#   80.83200073242188,
#   229.8560028076172,
#   'AC',
#   3,
#   1,
#   0),
#  (83.04000091552734,
#   220.80799865722656,
#   93.2280044555664,
#   229.8159942626953,
#   '21,',
#   3,
#   1,
#   1),
#  (95.43600463867188,
#   220.80799865722656,
#   114.31281280517578,
#   229.8159942626953,
#   'touch',
#   3,
#   1,
#   2),
#  (116.52081298828125,
#   220.80799865722656,
#   126.7024154663086,
#   229.8159942626953,
#   '15,',
#   3,
#   1,
#   3),
#  (128.91041564941406,
#   220.80799865722656,
#   164.53598022460938,
#   229.8159942626953,
#   'flat-footed',
#   3,
#   1,
#   4),
#  (166.74398803710938,
#   220.80799865722656,
#   174.93199157714844,
#   229.8159942626953,
#   '16',
#   3,
#   1,
#   5),
#  (177.13998413085938,
#   220.80799865722656,
#   187.99278259277344,
#   229.8159942626953,
#   '(+5',
#   3,
#   1,
#   6),
#  (190.20077514648438,
#   220.80799865722656,
#   205.51116943359375,
#   229.8159942626953,
#   'Dex,',
#   3,
#   1,
#   7),
#  (207.71917724609375,
#   220.80799865722656,
#   216.23117065429688,
#   229.8159942626953,
#   '+6',
#   3,
#   1,
#   8),
#  (218.43917846679688,
#   220.80799865722656,
#   245.63279724121094,
#   229.8159942626953,
#   'natural)',
#   3,
#   1,
#   9),
#  (72.0,
#   232.72000122070312,
#   81.33599853515625,
#   241.8560028076172,
#   'hp',
#   3,
#   2,
#   0),
#  (83.54399871826172,
#   232.80799865722656,
#   92.1343994140625,
#   241.8159942626953,
#   '84',
#   3,
#   2,
#   1),
#  (94.34239959716797,
#   232.80799865722656,
#   128.31039428710938,
#   241.8159942626953,
#   '(13d8+26)',
#   3,
#   2,
#   2),
#  (72.0,
#   244.72000122070312,
#   86.34160614013672,
#   253.8560028076172,
#   'Fort',
#   3,
#   3,
#   0),
#  (88.552001953125,
#   244.80799865722656,
#   99.16000366210938,
#   253.8159942626953,
#   '+6,',
#   3,
#   3,
#   1),
#  (101.36800384521484,
#   244.72000122070312,
#   113.43119812011719,
#   253.8560028076172,
#   'Ref',
#   3,
#   3,
#   2),
#  (115.63999938964844,
#   244.80799865722656,
#   125.72319793701172,
#   253.8159942626953,
#   '+9,',
#   3,
#   3,
#   3),
#  (127.93119812011719,
#   244.72000122070312,
#   141.8280029296875,
#   253.8560028076172,
#   'Will',
#   3,
#   3,
#   4),
#  (144.03199768066406,
#   244.80799865722656,
#   152.36000061035156,
#   253.8159942626953,
#   '+8',
#   3,
#   3,
#   5),
#  (72.00000762939453,
#   256.7200012207031,
#   81.82400512695312,
#   265.8559875488281,
#   'DR',
#   3,
#   4,
#   0),
#  (84.0320053100586,
#   256.8080139160156,
#   114.9664077758789,
#   265.8160095214844,
#   '5/magic;',
#   3,
#   4,
#   1),
#  (117.17601013183594,
#   256.7200012207031,
#   147.9872283935547,
#   265.8559875488281,
#   'Immune',
#   3,
#   4,
#   2),
#  (150.1920166015625,
#   256.8080139160156,
#   166.2176055908203,
#   265.8160095214844,
#   'cold,',
#   3,
#   4,
#   3),
#  (168.42559814453125,
#   256.8080139160156,
#   196.05755615234375,
#   265.8160095214844,
#   'disease,',
#   3,
#   4,
#   4),
#  (198.26556396484375,
#   256.8080139160156,
#   220.86874389648438,
#   265.8160095214844,
#   'poison',
#   3,
#   4,
#   5),
#  (72.0,
#   270.0849914550781,
#   95.32200622558594,
#   277.50799560546875,
#   'OFFENSE',
#   4,
#   0,
#   0),
#  (72.0,
#   280.7200012207031,
#   94.33599853515625,
#   289.8559875488281,
#   'Speed',
#   4,
#   1,
#   0),
#  (96.54399871826172,
#   280.8080139160156,
#   100.76799774169922,
#   289.8160095214844,
#   '5',
#   4,
#   1,
#   1),
#  (102.97599792480469,
#   280.8080139160156,
#   112.53520202636719,
#   289.8160095214844,
#   'ft.,',
#   4,
#   1,
#   2),
#  (114.74320220947266,
#   280.8080139160156,
#   123.05120086669922,
#   289.8160095214844,
#   'fly',
#   4,
#   1,
#   3),
#  (125.25920104980469,
#   280.8080139160156,
#   133.76719665527344,
#   289.8160095214844,
#   '50',
#   4,
#   1,
#   4),
#  (135.97518920898438,
#   280.8080139160156,
#   143.43357849121094,
#   289.8160095214844,
#   'ft.',
#   4,
#   1,
#   5),
#  (145.64157104492188,
#   280.8080139160156,
#   168.9087677001953,
#   289.8160095214844,
#   '(good)',
#   4,
#   1,
#   6),
#  (72.0,
#   292.7200012207031,
#   94.39199829101562,
#   301.8559875488281,
#   'Melee',
#   4,
#   2,
#   0),
#  (96.60800170898438,
#   292.8080139160156,
#   127.55520629882812,
#   301.8160095214844,
#   'tentacles',
#   4,
#   2,
#   1),
#  (129.76321411132812,
#   292.8080139160156,
#   141.552001953125,
#   301.8160095214844,
#   '+15',
#   4,
#   2,
#   2),
#  (143.760009765625,
#   292.8080139160156,
#   159.50001525878906,
#   301.8160095214844,
#   '(3d6',
#   4,
#   2,
#   3),
#  (161.7080078125,
#   292.8080139160156,
#   175.63441467285156,
#   301.8160095214844,
#   'plus',
#   4,
#   2,
#   4),
#  (177.8424072265625,
#   292.8080139160156,
#   193.27203369140625,
#   301.8160095214844,
#   'grab',
#   4,
#   2,
#   5),
#  (195.48004150390625,
#   292.8080139160156,
#   208.22166442871094,
#   301.8160095214844,
#   'and',
#   4,
#   2,
#   6),
#  (210.42965698242188,
#   292.8080139160156,
#   246.29762268066406,
#   301.8160095214844,
#   'withering)',
#   4,
#   2,
#   7),
#  (72.0,
#   304.7200012207031,
#   92.93120574951172,
#   313.8559875488281,
#   'Space',
#   4,
#   3,
#   0),
#  (95.14400482177734,
#   304.8080139160156,
#   99.36800384521484,
#   313.8160095214844,
#   '5',
#   4,
#   3,
#   1),
#  (101.57600402832031,
#   304.8080139160156,
#   111.13520812988281,
#   313.8160095214844,
#   'ft.;',
#   4,
#   3,
#   2),
#  (113.34320831298828,
#   304.7200012207031,
#   135.13121032714844,
#   313.8559875488281,
#   'Reach',
#   4,
#   3,
#   3),
#  (137.33599853515625,
#   304.8080139160156,
#   141.55999755859375,
#   313.8160095214844,
#   '5',
#   4,
#   3,
#   4),
#  (143.76800537109375,
#   304.8080139160156,
#   151.2263946533203,
#   313.8160095214844,
#   'ft.',
#   4,
#   3,
#   5),
#  (153.43438720703125,
#   304.8080139160156,
#   164.23599243164062,
#   313.8160095214844,
#   '(15',
#   4,
#   3,
#   6),
#  (166.44400024414062,
#   304.8080139160156,
#   173.90158081054688,
#   313.8160095214844,
#   'ft.',
#   4,
#   3,
#   7),
#  (176.10958862304688,
#   304.8080139160156,
#   191.34957885742188,
#   313.8160095214844,
#   'with',
#   4,
#   3,
#   8),
#  (193.55758666992188,
#   304.8080139160156,
#   227.09754943847656,
#   313.8160095214844,
#   'tentacles)',
#   4,
#   3,
#   9),
#  (72.00000762939453,
#   316.7200012207031,
#   97.77120971679688,
#   325.8559875488281,
#   'Special',
#   4,
#   4,
#   0),
#  (99.91520690917969,
#   316.7200012207031,
#   127.03681945800781,
#   325.8559875488281,
#   'Attacks',
#   4,
#   4,
#   1),
#  (129.24002075195312,
#   316.8080139160156,
#   158.11997985839844,
#   325.8160095214844,
#   'constrict',
#   4,
#   4,
#   2),
#  (160.32797241210938,
#   316.8080139160156,
#   176.06797790527344,
#   325.8160095214844,
#   '(3d6',
#   4,
#   4,
#   3),
#  (178.27597045898438,
#   316.8080139160156,
#   192.2031707763672,
#   325.8160095214844,
#   'plus',
#   4,
#   4,
#   4),
#  (194.41116333007812,
#   316.8080139160156,
#   232.27915954589844,
#   325.8160095214844,
#   'withering),',
#   4,
#   4,
#   5),
#  (234.48715209960938,
#   316.8080139160156,
#   255.18235778808594,
#   325.8160095214844,
#   'gnaw,',
#   4,
#   4,
#   6),
#  (257.3903503417969,
#   316.8080139160156,
#   270.029541015625,
#   325.8160095214844,
#   'pull',
#   4,
#   4,
#   7),
#  (81.00001525878906,
#   328.8080139160156,
#   116.8160171508789,
#   337.8160095214844,
#   '(tentacles,',
#   4,
#   5,
#   0),
#  (119.02401733398438,
#   328.8080139160156,
#   123.24801635742188,
#   337.8160095214844,
#   '5',
#   4,
#   5,
#   1),
#  (125.45601654052734,
#   328.8080139160156,
#   141.8400115966797,
#   337.8160095214844,
#   'feet)',
#   4,
#   5,
#   2),
#  (72.00001525878906,
#   340.7200012207031,
#   107.85282897949219,
#   349.8559875488281,
#   'Spell-Like',
#   4,
#   6,
#   0),
#  (109.99684143066406,
#   340.7200012207031,
#   140.25445556640625,
#   349.8559875488281,
#   'Abilities',
#   4,
#   6,
#   1),
#  (142.46401977539062,
#   340.8080139160156,
#   152.36163330078125,
#   349.8160095214844,
#   '(CL',
#   4,
#   6,
#   2),
#  (154.56964111328125,
#   340.8080139160156,
#   171.8096466064453,
#   349.8160095214844,
#   '13th;',
#   4,
#   6,
#   3),
#  (174.01763916015625,
#   340.8080139160156,
#   220.55679321289062,
#   349.8160095214844,
#   'concentration',
#   4,
#   6,
#   4),
#  (222.76480102539062,
#   340.8080139160156,
#   237.5255889892578,
#   349.8160095214844,
#   '+17)',
#   4,
#   6,
#   5),
#  (81.35201263427734,
#   352.8080139160156,
#   88.58401489257812,
#   361.8160095214844,
#   'At',
#   4,
#   7,
#   0),
#  (90.7920150756836,
#   352.8080139160156,
#   126.51361083984375,
#   361.8160095214844,
#   'will—calm',
#   4,
#   7,
#   1),
#  (128.72161865234375,
#   352.8080139160156,
#   160.8240203857422,
#   361.8160095214844,
#   'emotions',
#   4,
#   7,
#   2),
#  (163.03201293945312,
#   352.8080139160156,
#   174.57762145996094,
#   361.8160095214844,
#   '(DC',
#   4,
#   7,
#   3),
#  (176.78561401367188,
#   352.8080139160156,
#   189.63201904296875,
#   361.8160095214844,
#   '16),',
#   4,
#   7,
#   4),
#  (191.84002685546875,
#   352.8080139160156,
#   213.48562622070312,
#   361.8160095214844,
#   'charm',
#   4,
#   7,
#   5),
#  (215.69363403320312,
#   352.8080139160156,
#   244.08084106445312,
#   361.8160095214844,
#   'monster',
#   4,
#   7,
#   6),
#  (246.28884887695312,
#   352.8080139160156,
#   257.8344421386719,
#   361.8160095214844,
#   '(DC',
#   4,
#   7,
#   7),
#  (260.0424499511719,
#   352.8080139160156,
#   272.9248352050781,
#   361.8160095214844,
#   '18),',
#   4,
#   7,
#   8),
#  (90.35201263427734,
#   364.8080139160156,
#   182.84561157226562,
#   373.8160095214844,
#   'clairaudience/clairvoyance',
#   4,
#   8,
#   0),
#  (185.0560302734375,
#   364.8080139160156,
#   230.29443359375,
#   373.8160095214844,
#   '(clairvoyance',
#   4,
#   8,
#   1),
#  (232.50244140625,
#   364.8080139160156,
#   251.9392547607422,
#   373.8160095214844,
#   'only),',
#   4,
#   8,
#   2),
#  (254.14724731445312,
#   364.8080139160156,
#   270.3272399902344,
#   373.8160095214844,
#   'daze',
#   4,
#   8,
#   3),
#  (90.35202026367188,
#   376.8080139160156,
#   118.74002075195312,
#   385.8160095214844,
#   'monster',
#   4,
#   9,
#   0),
#  (120.95201873779297,
#   376.8080139160156,
#   132.4976348876953,
#   385.8160095214844,
#   '(DC',
#   4,
#   9,
#   1),
#  (134.70562744140625,
#   376.8080139160156,
#   147.55203247070312,
#   385.8160095214844,
#   '16),',
#   4,
#   9,
#   2),
#  (149.76004028320312,
#   376.8080139160156,
#   174.9032440185547,
#   385.8160095214844,
#   'feather',
#   4,
#   9,
#   3),
#  (177.1104278564453,
#   376.8080139160156,
#   188.0136260986328,
#   385.8160095214844,
#   'fall',
#   4,
#   9,
#   4),
#  (81.35202026367188,
#   388.8080139160156,
#   128.7608184814453,
#   397.8160095214844,
#   '3/day—dispel',
#   4,
#   10,
#   0),
#  (130.96881103515625,
#   388.8080139160156,
#   154.0080108642578,
#   397.8160095214844,
#   'magic,',
#   4,
#   10,
#   1),
#  (156.21600341796875,
#   388.8080139160156,
#   186.78001403808594,
#   397.8160095214844,
#   'lightning',
#   4,
#   10,
#   2),
#  (188.98800659179688,
#   388.8080139160156,
#   202.29519653320312,
#   397.8160095214844,
#   'bolt',
#   4,
#   10,
#   3),
#  (204.50320434570312,
#   388.8080139160156,
#   216.04881286621094,
#   397.8160095214844,
#   '(DC',
#   4,
#   10,
#   4),
#  (218.25680541992188,
#   388.8080139160156,
#   229.39759826660156,
#   397.8160095214844,
#   '17)',
#   4,
#   10,
#   5),
#  (81.35202026367188,
#   400.8080139160156,
#   141.59524536132812,
#   409.8160095214844,
#   '1/day—dominate',
#   4,
#   11,
#   0),
#  (143.80325317382812,
#   400.8080139160156,
#   172.19126892089844,
#   409.8160095214844,
#   'monster',
#   4,
#   11,
#   1),
#  (174.39926147460938,
#   400.8080139160156,
#   185.9448699951172,
#   409.8160095214844,
#   '(DC',
#   4,
#   11,
#   2),
#  (188.15286254882812,
#   400.8080139160156,
#   199.25526428222656,
#   409.8160095214844,
#   '23)',
#   4,
#   11,
#   3),
#  (81.35202026367188,
#   412.8080139160156,
#   168.03517150878906,
#   421.8160095214844,
#   '1/month—interplanetary',
#   4,
#   12,
#   0),
#  (170.24314880371094,
#   412.8080139160156,
#   204.19920349121094,
#   421.8160095214844,
#   'teleportUM',
#   4,
#   12,
#   1),
#  (72.0,
#   426.0849914550781,
#   100.57725524902344,
#   433.50799560546875,
#   'STATISTICS',
#   5,
#   0,
#   0),
#  (72.0,
#   436.7200012207031,
#   81.80720520019531,
#   445.8559875488281,
#   'Str',
#   5,
#   1,
#   0),
#  (84.01599884033203,
#   436.8080139160156,
#   93.91680145263672,
#   445.8160095214844,
#   '11,',
#   5,
#   1,
#   1),
#  (96.12480163574219,
#   436.7200012207031,
#   109.94879913330078,
#   445.8559875488281,
#   'Dex',
#   5,
#   1,
#   2),
#  (112.15999603271484,
#   436.8080139160156,
#   122.3479995727539,
#   445.8160095214844,
#   '21,',
#   5,
#   1,
#   3),
#  (124.55599975585938,
#   436.7200012207031,
#   137.69679260253906,
#   445.8559875488281,
#   'Con',
#   5,
#   1,
#   4),
#  (139.90399169921875,
#   436.8080139160156,
#   150.1687774658203,
#   445.8160095214844,
#   '14,',
#   5,
#   1,
#   5),
#  (152.37677001953125,
#   436.7200012207031,
#   162.50318908691406,
#   445.8559875488281,
#   'Int',
#   5,
#   1,
#   6),
#  (164.71200561523438,
#   436.8080139160156,
#   175.06320190429688,
#   445.8160095214844,
#   '18,',
#   5,
#   1,
#   7),
#  (177.27120971679688,
#   436.7200012207031,
#   189.9600067138672,
#   445.8559875488281,
#   'Wis',
#   5,
#   1,
#   8),
#  (192.16799926757812,
#   436.8080139160156,
#   202.44558715820312,
#   445.8160095214844,
#   '10,',
#   5,
#   1,
#   9),
#  (204.65359497070312,
#   436.7200012207031,
#   217.76480102539062,
#   445.8559875488281,
#   'Cha',
#   5,
#   1,
#   10),
#  (219.96800231933594,
#   436.8080139160156,
#   228.1439971923828,
#   445.8160095214844,
#   '19',
#   5,
#   1,
#   11),
#  (72.0, 448.7200012207031, 89.38720703125, 457.8559875488281, 'Base', 5, 2, 0),
#  (91.53120422363281,
#   448.7200012207031,
#   103.89120483398438,
#   457.8559875488281,
#   'Atk',
#   5,
#   2,
#   1),
#  (106.09920501708984,
#   448.8080139160156,
#   116.67840576171875,
#   457.8160095214844,
#   '+9;',
#   5,
#   2,
#   2),
#  (118.88640594482422,
#   448.7200012207031,
#   134.40000915527344,
#   457.8559875488281,
#   'CMB',
#   5,
#   2,
#   3),
#  (136.60800170898438,
#   448.8080139160156,
#   145.05599975585938,
#   457.8160095214844,
#   '+9',
#   5,
#   2,
#   4),
#  (147.26400756835938,
#   448.8080139160156,
#   161.6584014892578,
#   457.8160095214844,
#   '(+21',
#   5,
#   2,
#   5),
#  (163.86639404296875,
#   448.8080139160156,
#   194.72801208496094,
#   457.8160095214844,
#   'grapple);',
#   5,
#   2,
#   6),
#  (196.93600463867188,
#   448.7200012207031,
#   212.5944061279297,
#   457.8559875488281,
#   'CMD',
#   5,
#   2,
#   7),
#  (214.79998779296875,
#   448.8080139160156,
#   223.069580078125,
#   457.8160095214844,
#   '24',
#   5,
#   2,
#   8),
#  (225.277587890625,
#   448.8080139160156,
#   236.41839599609375,
#   457.8160095214844,
#   '(32',
#   5,
#   2,
#   9),
#  (238.62640380859375,
#   448.8080139160156,
#   247.98159790039062,
#   457.8160095214844,
#   'vs.',
#   5,
#   2,
#   10),
#  (81.0,
#   460.8080139160156,
#   109.24160766601562,
#   469.8160095214844,
#   'grapple,',
#   5,
#   3,
#   0),
#  (111.4496078491211,
#   460.8080139160156,
#   127.93840789794922,
#   469.8160095214844,
#   'can’t',
#   5,
#   3,
#   1),
#  (130.1464080810547,
#   460.8080139160156,
#   138.68479919433594,
#   469.8160095214844,
#   'be',
#   5,
#   3,
#   2),
#  (140.89279174804688,
#   460.8080139160156,
#   168.66317749023438,
#   469.8160095214844,
#   'tripped)',
#   5,
#   3,
#   3),
#  (72.0,
#   472.7200012207031,
#   90.74960327148438,
#   481.8559875488281,
#   'Feats',
#   5,
#   4,
#   0),
#  (92.79999542236328,
#   472.8080139160156,
#   118.36000061035156,
#   481.8160095214844,
#   'Combat',
#   5,
#   4,
#   1),
#  (120.40799713134766,
#   472.8080139160156,
#   150.58316040039062,
#   481.8160095214844,
#   'Reflexes,',
#   5,
#   4,
#   2),
#  (152.6311798095703,
#   472.8080139160156,
#   174.9600067138672,
#   481.8160095214844,
#   'Critical',
#   5,
#   4,
#   3),
#  (177.0080108642578,
#   472.8080139160156,
#   197.58316040039062,
#   481.8160095214844,
#   'Focus,',
#   5,
#   4,
#   4),
#  (199.6311798095703,
#   472.8080139160156,
#   217.12876892089844,
#   481.8160095214844,
#   'Flyby',
#   5,
#   4,
#   5),
#  (219.17677307128906,
#   472.8080139160156,
#   242.54957580566406,
#   481.8160095214844,
#   'Attack,',
#   5,
#   4,
#   6),
#  (81.0,
#   484.8080139160156,
#   105.40650177001953,
#   493.8160095214844,
#   'HoverB,',
#   5,
#   5,
#   0),
#  (107.45449829101562,
#   484.8080139160156,
#   139.46249389648438,
#   493.8160095214844,
#   'Improved',
#   5,
#   5,
#   1),
#  (141.510498046875,
#   484.8080139160156,
#   172.83212280273438,
#   493.8160095214844,
#   'Initiative,',
#   5,
#   5,
#   2),
#  (174.88014221191406,
#   484.8080139160156,
#   188.36814880371094,
#   493.8160095214844,
#   'Skill',
#   5,
#   5,
#   3),
#  (190.41615295410156,
#   484.8080139160156,
#   208.9305419921875,
#   493.8160095214844,
#   'Focus',
#   5,
#   5,
#   4),
#  (210.97854614257812,
#   484.8080139160156,
#   253.6377410888672,
#   493.8160095214844,
#   '(Perception),',
#   5,
#   5,
#   5),
#  (81.0,
#   496.8080139160156,
#   107.66741943359375,
#   505.8160095214844,
#   'Weapon',
#   6,
#   0,
#   0),
#  (109.48188781738281,
#   496.8080139160156,
#   135.40562438964844,
#   505.8160095214844,
#   'Finesse,',
#   6,
#   0,
#   1),
#  (137.22010803222656,
#   496.8080139160156,
#   163.8875732421875,
#   505.8160095214844,
#   'Weapon',
#   6,
#   0,
#   2),
#  (165.70126342773438,
#   496.8080139160156,
#   183.71376037597656,
#   505.8160095214844,
#   'Focus',
#   6,
#   0,
#   3),
#  (185.5282440185547,
#   496.8080139160156,
#   218.54830932617188,
#   505.8160095214844,
#   '(tentacle),',
#   6,
#   0,
#   4),
#  (220.36199951171875,
#   496.8080139160156,
#   254.00009155273438,
#   505.8160095214844,
#   'WingoverB',
#   6,
#   0,
#   5),
#  (72.0,
#   508.7200012207031,
#   91.13999938964844,
#   517.8560180664062,
#   'Skills',
#   7,
#   0,
#   0),
#  (93.34400177001953,
#   508.8080139160156,
#   128.2200164794922,
#   517.8159790039062,
#   'Acrobatics',
#   7,
#   0,
#   1),
#  (130.42800903320312,
#   508.8080139160156,
#   144.21359252929688,
#   517.8159790039062,
#   '+21,',
#   7,
#   0,
#   2),
#  (146.42160034179688,
#   508.8080139160156,
#   182.48080444335938,
#   517.8159790039062,
#   'Diplomacy',
#   7,
#   0,
#   3),
#  (184.68881225585938,
#   508.8080139160156,
#   197.87359619140625,
#   517.8159790039062,
#   '+17,',
#   7,
#   0,
#   4),
#  (200.08160400390625,
#   508.8080139160156,
#   209.61441040039062,
#   517.8159790039062,
#   'Fly',
#   7,
#   0,
#   5),
#  (211.82241821289062,
#   508.8080139160156,
#   225.86241149902344,
#   517.8159790039062,
#   '+20,',
#   7,
#   0,
#   6),
#  (81.0,
#   520.8079833984375,
#   119.52241516113281,
#   529.8159790039062,
#   'Knowledge',
#   7,
#   1,
#   0),
#  (121.73041534423828,
#   520.8079833984375,
#   149.57762145996094,
#   529.8159790039062,
#   '(arcana)',
#   7,
#   1,
#   1),
#  (151.78561401367188,
#   520.8079833984375,
#   165.6696014404297,
#   529.8159790039062,
#   '+14,',
#   7,
#   1,
#   2),
#  (167.87759399414062,
#   520.8079833984375,
#   204.04156494140625,
#   529.8159790039062,
#   'Perception',
#   7,
#   1,
#   3),
#  (206.24957275390625,
#   520.8079833984375,
#   220.41036987304688,
#   529.8159790039062,
#   '+28,',
#   7,
#   1,
#   4),
#  (222.61837768554688,
#   520.8079833984375,
#   242.65435791015625,
#   529.8159790039062,
#   'Sense',
#   7,
#   1,
#   5),
#  (81.0,
#   532.8079833984375,
#   104.37999725341797,
#   541.8159790039062,
#   'Motive',
#   7,
#   2,
#   0),
#  (106.58799743652344,
#   532.8079833984375,
#   120.42479705810547,
#   541.8159790039062,
#   '+13,',
#   7,
#   2,
#   1),
#  (122.63279724121094,
#   532.8079833984375,
#   154.63357543945312,
#   541.8159790039062,
#   'Spellcraft',
#   7,
#   2,
#   2),
#  (156.84158325195312,
#   532.8079833984375,
#   170.64315795898438,
#   541.8159790039062,
#   '+15,',
#   7,
#   2,
#   3),
#  (172.85116577148438,
#   532.8079833984375,
#   196.34075927734375,
#   541.8159790039062,
#   'Stealth',
#   7,
#   2,
#   4),
#  (198.54876708984375,
#   532.8079833984375,
#   212.3343505859375,
#   541.8159790039062,
#   '+21,',
#   7,
#   2,
#   5),
#  (214.5423583984375,
#   532.8079833984375,
#   226.7967529296875,
#   541.8159790039062,
#   'Use',
#   7,
#   2,
#   6),
#  (229.0047607421875,
#   532.8079833984375,
#   249.1735382080078,
#   541.8159790039062,
#   'Magic',
#   7,
#   2,
#   7),
#  (81.0,
#   544.8079833984375,
#   103.64720916748047,
#   553.8159790039062,
#   'Device',
#   7,
#   3,
#   0),
#  (105.85520935058594,
#   544.8079833984375,
#   119.35121154785156,
#   553.8159790039062,
#   '+17;',
#   7,
#   3,
#   1),
#  (121.55921173095703,
#   544.719970703125,
#   143.3376007080078,
#   553.8560180664062,
#   'Racial',
#   7,
#   3,
#   2),
#  (145.48159790039062,
#   544.719970703125,
#   179.63999938964844,
#   553.8560180664062,
#   'Modifiers',
#   7,
#   3,
#   3),
#  (181.84800720214844,
#   544.8079833984375,
#   190.36000061035156,
#   553.8159790039062,
#   '+6',
#   7,
#   3,
#   4),
#  (192.56800842285156,
#   544.8079833984375,
#   228.72723388671875,
#   553.8159790039062,
#   'Perception',
#   7,
#   3,
#   5),
#  (72.0,
#   556.719970703125,
#   110.09359741210938,
#   565.8560180664062,
#   'Languages',
#   7,
#   4,
#   0),
#  (111.98400115966797,
#   556.8079833984375,
#   128.52560424804688,
#   565.8159790039062,
#   'Aklo,',
#   7,
#   4,
#   1),
#  (130.4136199951172,
#   556.8079833984375,
#   162.05999755859375,
#   565.8159790039062,
#   'Common,',
#   7,
#   4,
#   2),
#  (163.94801330566406,
#   556.8079833984375,
#   193.9720001220703,
#   565.8159790039062,
#   'Draconic,',
#   7,
#   4,
#   3),
#  (195.86001586914062,
#   556.8079833984375,
#   246.46640014648438,
#   565.8159790039062,
#   'Undercommon;',
#   7,
#   4,
#   4),
#  (81.0,
#   568.8079833984375,
#   112.75440216064453,
#   577.8159790039062,
#   'telepathy',
#   7,
#   5,
#   0),
#  (114.80239868164062,
#   568.8079833984375,
#   127.29039001464844,
#   577.8159790039062,
#   '100',
#   7,
#   5,
#   1),
#  (129.33839416503906,
#   568.8079833984375,
#   136.6367950439453,
#   577.8159790039062,
#   'ft.',
#   7,
#   5,
#   2),
#  (72.0, 580.719970703125, 80.99600219726562, 589.8560180664062, 'SQ', 7, 6, 0),
#  (83.19999694824219,
#   580.8079833984375,
#   128.25201416015625,
#   589.8159790039062,
#   'compression,',
#   7,
#   6,
#   1),
#  (130.46002197265625,
#   580.8079833984375,
#   148.02479553222656,
#   589.8159790039062,
#   'float,',
#   7,
#   6,
#   2),
#  (150.2327880859375,
#   580.8079833984375,
#   158.8127899169922,
#   589.8159790039062,
#   'no',
#   7,
#   6,
#   3),
#  (161.02078247070312,
#   580.8079833984375,
#   183.08795166015625,
#   589.8159790039062,
#   'breath',
#   7,
#   6,
#   4),
#  (72.0,
#   594.0850219726562,
#   95.99474334716797,
#   601.5079956054688,
#   'ECOLOGY',
#   8,
#   0,
#   0),
#  (72.0,
#   604.719970703125,
#   117.96000671386719,
#   613.8560180664062,
#   'Environment',
#   8,
#   1,
#   0),
#  (120.00800323486328,
#   604.8079833984375,
#   132.17601013183594,
#   613.8159790039062,
#   'any',
#   8,
#   1,
#   1),
#  (134.22401428222656,
#   604.8079833984375,
#   148.7520294189453,
#   613.8159790039062,
#   'land',
#   8,
#   1,
#   2),
#  (72.0,
#   616.719970703125,
#   116.78284454345703,
#   625.8560180664062,
#   'Organization',
#   9,
#   0,
#   0),
#  (118.65672302246094,
#   616.8079833984375,
#   144.28347778320312,
#   625.8159790039062,
#   'solitary,',
#   9,
#   0,
#   1),
#  (146.15260314941406,
#   616.8079833984375,
#   160.27951049804688,
#   625.8159790039062,
#   'pair,',
#   9,
#   0,
#   2),
#  (162.1486358642578,
#   616.8079833984375,
#   174.59573364257812,
#   625.8159790039062,
#   'pod',
#   9,
#   0,
#   3),
#  (176.46485900878906,
#   616.8079833984375,
#   195.20751953125,
#   625.8159790039062,
#   '(3–5),',
#   9,
#   0,
#   4),
#  (197.07664489746094,
#   616.8079833984375,
#   203.74212646484375,
#   625.8159790039062,
#   'or',
#   9,
#   0,
#   5),
#  (205.6112518310547,
#   616.8079833984375,
#   232.60658264160156,
#   625.8159790039062,
#   'invasion',
#   9,
#   0,
#   6),
#  (234.4757080078125,
#   616.8079833984375,
#   254.8942413330078,
#   625.8159790039062,
#   '(6–36)',
#   9,
#   0,
#   7),
#  (72.0,
#   628.719970703125,
#   102.38478088378906,
#   637.8560180664062,
#   'Treasure',
#   9,
#   1,
#   0),
#  (104.43199920654297,
#   628.8079833984375,
#   133.66639709472656,
#   637.8159790039062,
#   'standard',
#   9,
#   1,
#   1),
#  (72.0,
#   642.0850219726562,
#   93.68920135498047,
#   649.5079956054688,
#   'SPECIAL',
#   10,
#   0,
#   0),
#  (95.43119812011719,
#   642.0850219726562,
#   121.06069946289062,
#   649.5079956054688,
#   'ABILITIES',
#   10,
#   0,
#   1),
#  (72.0,
#   652.719970703125,
#   92.56879425048828,
#   661.8560180664062,
#   'Gnaw',
#   10,
#   1,
#   0),
#  (94.7127914428711,
#   652.719970703125,
#   109.09598541259766,
#   661.8560180664062,
#   '(Ex)',
#   10,
#   1,
#   1),
#  (111.30398559570312,
#   652.8079833984375,
#   130.92239379882812,
#   661.8159790039062,
#   'When',
#   10,
#   1,
#   2),
#  (133.13040161132812,
#   652.8079833984375,
#   141.53121948242188,
#   661.8159790039062,
#   'an',
#   10,
#   1,
#   3),
#  (143.73922729492188,
#   652.8079833984375,
#   180.14720153808594,
#   661.8159790039062,
#   'aatheriexa',
#   10,
#   1,
#   4),
#  (182.35519409179688,
#   652.8079833984375,
#   204.26158142089844,
#   661.8159790039062,
#   'shares',
#   10,
#   1,
#   5),
#  (206.46957397460938,
#   652.8079833984375,
#   217.72315979003906,
#   661.8159790039062,
#   'the',
#   10,
#   1,
#   6),
#  (219.93115234375,
#   652.8079833984375,
#   238.48394775390625,
#   661.8159790039062,
#   'same',
#   10,
#   1,
#   7),
#  (240.69195556640625,
#   652.8079833984375,
#   263.5863342285156,
#   661.8159790039062,
#   'square',
#   10,
#   1,
#   8),
#  (265.7943420410156,
#   652.8079833984375,
#   273.1311340332031,
#   661.8159790039062,
#   'as',
#   10,
#   1,
#   9),
#  (275.3391418457031,
#   652.8079833984375,
#   279.3311462402344,
#   661.8159790039062,
#   'a',
#   10,
#   1,
#   10),
#  (81.0,
#   664.8079833984375,
#   108.968017578125,
#   673.8159790039062,
#   'helpless',
#   10,
#   2,
#   0),
#  (111.17601776123047,
#   664.8079833984375,
#   141.20960998535156,
#   673.8159790039062,
#   'creature,',
#   10,
#   2,
#   1),
#  (143.4176025390625,
#   664.8079833984375,
#   147.9951934814453,
#   673.8159790039062,
#   'it',
#   10,
#   2,
#   2),
#  (150.20318603515625,
#   664.8079833984375,
#   162.01199340820312,
#   673.8159790039062,
#   'can',
#   10,
#   2,
#   3),
#  (164.22000122070312,
#   664.8079833984375,
#   210.5599822998047,
#   673.8159790039062,
#   'automatically',
#   10,
#   2,
#   4),
#  (212.76797485351562,
#   664.8079833984375,
#   227.37118530273438,
#   673.8159790039062,
#   'deal',
#   10,
#   2,
#   5),
#  (229.57919311523438,
#   664.8079833984375,
#   242.45199584960938,
#   673.8159790039062,
#   '3d6',
#   10,
#   2,
#   6),
#  (244.66000366210938,
#   664.8079833984375,
#   265.70477294921875,
#   673.8159790039062,
#   'points',
#   10,
#   2,
#   7),
#  (267.91278076171875,
#   664.8079833984375,
#   274.598388671875,
#   673.8159790039062,
#   'of',
#   10,
#   2,
#   8),
#  (81.0,
#   676.8079833984375,
#   108.89360809326172,
#   685.8159790039062,
#   'damage',
#   10,
#   3,
#   0),
#  (111.10160827636719,
#   676.8079833984375,
#   118.43760681152344,
#   685.8159790039062,
#   'as',
#   10,
#   3,
#   1),
#  (120.6456069946289,
#   676.8079833984375,
#   124.63760375976562,
#   685.8159790039062,
#   'a',
#   10,
#   3,
#   2),
#  (126.8456039428711,
#   676.8079833984375,
#   143.82559204101562,
#   685.8159790039062,
#   'swift',
#   10,
#   3,
#   3),
#  (146.03359985351562,
#   676.8079833984375,
#   166.965576171875,
#   685.8159790039062,
#   'action',
#   10,
#   3,
#   4),
#  (169.173583984375,
#   676.8079833984375,
#   177.3015899658203,
#   685.8159790039062,
#   'by',
#   10,
#   3,
#   5),
#  (179.50958251953125,
#   676.8079833984375,
#   209.173583984375,
#   685.8159790039062,
#   'gnawing',
#   10,
#   3,
#   6),
#  (211.381591796875,
#   676.8079833984375,
#   226.62158203125,
#   685.8159790039062,
#   'with',
#   10,
#   3,
#   7),
#  (228.82958984375,
#   676.8079833984375,
#   236.87196350097656,
#   685.8159790039062,
#   'its',
#   10,
#   3,
#   8),
#  (239.0799560546875,
#   676.8079833984375,
#   262.3751220703125,
#   685.8159790039062,
#   'central',
#   10,
#   3,
#   9),
#  (264.5831298828125,
#   676.8079833984375,
#   283.3047180175781,
#   685.8159790039062,
#   'maw.',
#   10,
#   3,
#   10),
#  (72.0,
#   688.719970703125,
#   89.9511947631836,
#   697.8560180664062,
#   'Float',
#   10,
#   4,
#   0),
#  (92.0951919555664,
#   688.719970703125,
#   106.47918701171875,
#   697.8560180664062,
#   '(Ex)',
#   10,
#   4,
#   1),
#  (108.68718719482422,
#   688.8079833984375,
#   145.8743896484375,
#   697.8159790039062,
#   'Aatheriexa',
#   10,
#   4,
#   2),
#  (148.0823974609375,
#   688.8079833984375,
#   159.89120483398438,
#   697.8159790039062,
#   'can',
#   10,
#   4,
#   3),
#  (162.09921264648438,
#   688.8079833984375,
#   172.2016143798828,
#   697.8159790039062,
#   'fly,',
#   10,
#   4,
#   4),
#  (174.40960693359375,
#   688.8079833984375,
#   198.75119018554688,
#   697.8159790039062,
#   'though',
#   10,
#   4,
#   5),
#  (200.95919799804688,
#   688.8079833984375,
#   216.14639282226562,
#   697.8159790039062,
#   'they',
#   10,
#   4,
#   6),
#  (218.35440063476562,
#   688.8079833984375,
#   235.410400390625,
#   697.8159790039062,
#   'must',
#   10,
#   4,
#   7),
#  (237.618408203125,
#   688.8079833984375,
#   261.6656188964844,
#   697.8159790039062,
#   'remain',
#   10,
#   4,
#   8),
#  (263.8736267089844,
#   688.8079833984375,
#   279.1136169433594,
#   697.8159790039062,
#   'with',
#   10,
#   4,
#   9),
#  (281.3216247558594,
#   688.8079833984375,
#   285.5456237792969,
#   697.8159790039062,
#   '2',
#   10,
#   4,
#   10),
#  (81.0,
#   700.8079833984375,
#   94.6152114868164,
#   709.8159790039062,
#   'feet',
#   10,
#   5,
#   0),
#  (96.82321166992188,
#   700.8079833984375,
#   103.5088119506836,
#   709.8159790039062,
#   'of',
#   10,
#   5,
#   1),
#  (105.71681213378906,
#   700.8079833984375,
#   109.70880889892578,
#   709.8159790039062,
#   'a',
#   10,
#   5,
#   2),
#  (111.91680908203125,
#   700.8079833984375,
#   127.86241912841797,
#   709.8159790039062,
#   'solid',
#   10,
#   5,
#   3),
#  (130.07041931152344,
#   700.8079833984375,
#   136.96322631835938,
#   709.8159790039062,
#   'or',
#   10,
#   5,
#   4),
#  (139.17123413085938,
#   700.8079833984375,
#   158.176025390625,
#   709.8159790039062,
#   'liquid',
#   10,
#   5,
#   5),
#  (160.384033203125,
#   700.8079833984375,
#   187.11839294433594,
#   709.8159790039062,
#   'surface.',
#   10,
#   5,
#   6),
#  (312.0,
#   76.72000122070312,
#   346.0752258300781,
#   85.85600280761719,
#   'Tentacles',
#   11,
#   0,
#   0),
#  (348.2192687988281,
#   76.72000122070312,
#   362.60247802734375,
#   85.85600280761719,
#   '(Ex)',
#   11,
#   0,
#   1),
#  (364.8160095214844,
#   76.80799865722656,
#   373.9640197753906,
#   85.81600189208984,
#   'An',
#   11,
#   0,
#   2),
#  (376.1720275878906,
#   76.80799865722656,
#   417.7008056640625,
#   85.81600189208984,
#   'aatheriexa’s',
#   11,
#   0,
#   3),
#  (419.9088134765625,
#   76.80799865722656,
#   444.05279541015625,
#   85.81600189208984,
#   'barbed',
#   11,
#   0,
#   4),
#  (446.26080322265625,
#   76.80799865722656,
#   474.7223815917969,
#   85.81600189208984,
#   'eyestalk',
#   11,
#   0,
#   5),
#  (476.9303894042969,
#   76.80799865722656,
#   507.87835693359375,
#   85.81600189208984,
#   'tentacles',
#   11,
#   0,
#   6),
#  (510.08636474609375,
#   76.80799865722656,
#   527.1415405273438,
#   85.81600189208984,
#   'must',
#   11,
#   0,
#   7),
#  (321.0,
#   88.80799865722656,
#   329.10321044921875,
#   97.81600189208984,
#   'all',
#   11,
#   1,
#   0),
#  (331.31121826171875,
#   88.80799865722656,
#   350.0495910644531,
#   97.81600189208984,
#   'strike',
#   11,
#   1,
#   1),
#  (352.2575988769531,
#   88.80799865722656,
#   358.85760498046875,
#   97.81600189208984,
#   'at',
#   11,
#   1,
#   2),
#  (361.06561279296875,
#   88.80799865722656,
#   365.0576171875,
#   97.81600189208984,
#   'a',
#   11,
#   1,
#   3),
#  (367.265625,
#   88.80799865722656,
#   387.5888671875,
#   97.81600189208984,
#   'single',
#   11,
#   1,
#   4),
#  (389.796875,
#   88.80799865722656,
#   412.5480651855469,
#   97.81600189208984,
#   'target,',
#   11,
#   1,
#   5),
#  (414.7560729980469,
#   88.80799865722656,
#   425.95684814453125,
#   97.81600189208984,
#   'but',
#   11,
#   1,
#   6),
#  (428.16485595703125,
#   88.80799865722656,
#   443.35284423828125,
#   97.81600189208984,
#   'they',
#   11,
#   1,
#   7),
#  (445.56085205078125,
#   88.80799865722656,
#   454.10406494140625,
#   97.81600189208984,
#   'do',
#   11,
#   1,
#   8),
#  (456.31207275390625,
#   88.80799865722656,
#   463.8384704589844,
#   97.81600189208984,
#   'so',
#   11,
#   1,
#   9),
#  (466.0464782714844,
#   88.80799865722656,
#   473.3832702636719,
#   97.81600189208984,
#   'as',
#   11,
#   1,
#   10),
#  (475.5912780761719,
#   88.80799865722656,
#   479.5832824707031,
#   97.81600189208984,
#   'a',
#   11,
#   1,
#   11),
#  (481.7912902832031,
#   88.80799865722656,
#   508.67047119140625,
#   97.81600189208984,
#   'primary',
#   11,
#   1,
#   12),
#  (321.0,
#   100.80799865722656,
#   344.0848083496094,
#   109.81600189208984,
#   'attack.',
#   11,
#   2,
#   0),
#  (346.2928161621094,
#   100.80799865722656,
#   358.43280029296875,
#   109.81600189208984,
#   'The',
#   11,
#   2,
#   1),
#  (360.64080810546875,
#   100.80799865722656,
#   391.5887756347656,
#   109.81600189208984,
#   'tentacles',
#   11,
#   2,
#   2),
#  (393.7967834472656,
#   100.80799865722656,
#   408.3992004394531,
#   109.81600189208984,
#   'deal',
#   11,
#   2,
#   3),
#  (410.6072082519531,
#   100.80799865722656,
#   453.7336730957031,
#   109.81600189208984,
#   'bludgeoning',
#   11,
#   2,
#   4),
#  (455.9416809082031,
#   100.80799865722656,
#   468.68328857421875,
#   109.81600189208984,
#   'and',
#   11,
#   2,
#   5),
#  (470.89129638671875,
#   100.80799865722656,
#   498.6881103515625,
#   109.81600189208984,
#   'slashing',
#   11,
#   2,
#   6),
#  (500.8961181640625,
#   100.80799865722656,
#   528.7890014648438,
#   109.81600189208984,
#   'damage',
#   11,
#   2,
#   7),
#  (321.0,
#   112.80799865722656,
#   333.7416076660156,
#   121.81600189208984,
#   'and',
#   11,
#   3,
#   0),
#  (335.9496154785156,
#   112.80799865722656,
#   354.0360107421875,
#   121.81600189208984,
#   'grant',
#   11,
#   3,
#   1),
#  (356.2440185546875,
#   112.80799865722656,
#   367.49761962890625,
#   121.81600189208984,
#   'the',
#   11,
#   3,
#   2),
#  (369.70562744140625,
#   112.80799865722656,
#   406.11358642578125,
#   121.81600189208984,
#   'aatheriexa',
#   11,
#   3,
#   3),
#  (408.32159423828125,
#   112.80799865722656,
#   412.3135986328125,
#   121.81600189208984,
#   'a',
#   11,
#   3,
#   4),
#  (414.5216064453125,
#   112.80799865722656,
#   422.8511962890625,
#   121.81600189208984,
#   '+8',
#   11,
#   3,
#   5),
#  (425.0592041015625,
#   112.80799865722656,
#   445.6663818359375,
#   121.81600189208984,
#   'bonus',
#   11,
#   3,
#   6),
#  (447.8743896484375,
#   112.80799865722656,
#   456.4552001953125,
#   121.81600189208984,
#   'on',
#   11,
#   3,
#   7),
#  (458.6632080078125,
#   112.80799865722656,
#   484.808837890625,
#   121.81600189208984,
#   'grapple',
#   11,
#   3,
#   8),
#  (487.016845703125,
#   112.80799865722656,
#   512.4088745117188,
#   121.81600189208984,
#   'combat',
#   11,
#   3,
#   9),
#  (321.0,
#   124.80799865722656,
#   355.6664123535156,
#   133.8159942626953,
#   'maneuver',
#   11,
#   4,
#   0),
#  (357.8743896484375,
#   124.80799865722656,
#   382.8648376464844,
#   133.8159942626953,
#   'checks.',
#   11,
#   4,
#   1),
#  (312.0,
#   136.72000122070312,
#   348.9464416503906,
#   145.8560028076172,
#   'Withering',
#   11,
#   5,
#   0),
#  (351.2504577636719,
#   136.72000122070312,
#   365.8744812011719,
#   145.8560028076172,
#   '(Ex)',
#   11,
#   5,
#   1),
#  (368.239990234375,
#   136.80799865722656,
#   377.468017578125,
#   145.8159942626953,
#   'An',
#   11,
#   5,
#   2),
#  (379.83599853515625,
#   136.80799865722656,
#   422.24395751953125,
#   145.8159942626953,
#   'aatheriexa’s',
#   11,
#   5,
#   3),
#  (424.6119689941406,
#   136.80799865722656,
#   456.1999816894531,
#   145.8159942626953,
#   'tentacles',
#   11,
#   5,
#   4),
#  (458.5679931640625,
#   136.80799865722656,
#   483.6504211425781,
#   145.8159942626953,
#   'secrete',
#   11,
#   5,
#   5),
#  (486.0184326171875,
#   136.80799865722656,
#   490.01043701171875,
#   145.8159942626953,
#   'a',
#   11,
#   5,
#   6),
#  (492.37841796875,
#   136.80799865722656,
#   509.6759948730469,
#   145.8159942626953,
#   'toxin',
#   11,
#   5,
#   7),
#  (321.0,
#   148.80799865722656,
#   334.8711853027344,
#   157.8159942626953,
#   'that',
#   11,
#   6,
#   0),
#  (337.23919677734375,
#   148.80799865722656,
#   360.3536071777344,
#   157.8159942626953,
#   'causes',
#   11,
#   6,
#   1),
#  (362.72161865234375,
#   148.80799865722656,
#   379.251220703125,
#   157.8159942626953,
#   'flesh',
#   11,
#   6,
#   2),
#  (381.61920166015625,
#   148.80799865722656,
#   388.44000244140625,
#   157.8159942626953,
#   'to',
#   11,
#   6,
#   3),
#  (390.8079833984375,
#   148.80799865722656,
#   414.31591796875,
#   157.8159942626953,
#   'swiftly',
#   11,
#   6,
#   4),
#  (416.6839294433594,
#   148.80799865722656,
#   426.1935119628906,
#   157.8159942626953,
#   'rot',
#   11,
#   6,
#   5),
#  (428.5615234375,
#   148.80799865722656,
#   441.4631042480469,
#   157.8159942626953,
#   'and',
#   11,
#   6,
#   6),
#  (443.8310852050781,
#   148.80799865722656,
#   466.86785888671875,
#   157.8159942626953,
#   'slough',
#   11,
#   6,
#   7),
#  (469.23583984375,
#   148.80799865722656,
#   478.8310241699219,
#   157.8159942626953,
#   'off',
#   11,
#   6,
#   8),
#  (481.1990051269531,
#   148.80799865722656,
#   492.61260986328125,
#   157.8159942626953,
#   'the',
#   11,
#   6,
#   9),
#  (494.9806213378906,
#   148.80799865722656,
#   514.5813598632812,
#   157.8159942626953,
#   'bone.',
#   11,
#   6,
#   10),
#  (516.9494018554688,
#   148.80799865722656,
#   521.62939453125,
#   157.8159942626953,
#   'A',
#   11,
#   6,
#   11),
#  (321.0,
#   160.80799865722656,
#   349.49761962890625,
#   169.8159942626953,
#   'creature',
#   11,
#   7,
#   0),
#  (351.8656311035156,
#   160.80799865722656,
#   384.6015930175781,
#   169.8159942626953,
#   'damaged',
#   11,
#   7,
#   1),
#  (386.9695739746094,
#   160.80799865722656,
#   395.1767578125,
#   169.8159942626953,
#   'by',
#   11,
#   7,
#   2),
#  (397.5447692871094,
#   160.80799865722656,
#   406.02557373046875,
#   169.8159942626953,
#   'an',
#   11,
#   7,
#   3),
#  (408.3935546875,
#   160.80799865722656,
#   450.80230712890625,
#   169.8159942626953,
#   'aatheriexa’s',
#   11,
#   7,
#   4),
#  (453.1703186035156,
#   160.80799865722656,
#   484.7583312988281,
#   169.8159942626953,
#   'tentacles',
#   11,
#   7,
#   5),
#  (487.1263427734375,
#   160.80799865722656,
#   494.09912109375,
#   169.8159942626953,
#   'or',
#   11,
#   7,
#   6),
#  (496.4671325683594,
#   160.80799865722656,
#   525.9871215820312,
#   169.8159942626953,
#   'constrict',
#   11,
#   7,
#   7),
#  (321.0,
#   172.80799865722656,
#   342.2616271972656,
#   181.8159942626953,
#   'attack',
#   11,
#   8,
#   0),
#  (344.6296081542969,
#   172.80799865722656,
#   361.92559814453125,
#   181.8159942626953,
#   'must',
#   11,
#   8,
#   1),
#  (364.2936096191406,
#   172.80799865722656,
#   391.81365966796875,
#   181.8159942626953,
#   'succeed',
#   11,
#   8,
#   2),
#  (394.181640625,
#   172.80799865722656,
#   400.86163330078125,
#   181.8159942626953,
#   'at',
#   11,
#   8,
#   3),
#  (403.2296447753906,
#   172.80799865722656,
#   407.2216491699219,
#   181.8159942626953,
#   'a',
#   11,
#   8,
#   4),
#  (409.5896301269531,
#   172.80799865722656,
#   418.4040222167969,
#   181.8159942626953,
#   'DC',
#   11,
#   8,
#   5),
#  (420.7720031738281,
#   172.80799865722656,
#   429.0807800292969,
#   181.8159942626953,
#   '18',
#   11,
#   8,
#   6),
#  (431.4487609863281,
#   172.80799865722656,
#   463.0679626464844,
#   181.8159942626953,
#   'Fortitude',
#   11,
#   8,
#   7),
#  (465.43597412109375,
#   172.80799865722656,
#   481.1871643066406,
#   181.8159942626953,
#   'save',
#   11,
#   8,
#   8),
#  (483.55517578125,
#   172.80799865722656,
#   490.5279541015625,
#   181.8159942626953,
#   'or',
#   11,
#   8,
#   9),
#  (492.8959655761719,
#   172.80799865722656,
#   507.89276123046875,
#   181.8159942626953,
#   'take',
#   11,
#   8,
#   10),
#  (510.2607727050781,
#   172.80799865722656,
#   522.9503784179688,
#   181.8159942626953,
#   '1d4',
#   11,
#   8,
#   11),
#  (321.0,
#   184.80799865722656,
#   342.445556640625,
#   193.8159942626953,
#   'points',
#   11,
#   9,
#   0),
#  (344.8135681152344,
#   184.80799865722656,
#   351.57916259765625,
#   193.8159942626953,
#   'of',
#   11,
#   9,
#   1),
#  (353.9471435546875,
#   184.80799865722656,
#   383.3487548828125,
#   193.8159942626953,
#   'Strength',
#   11,
#   9,
#   2),
#  (385.71673583984375,
#   184.80799865722656,
#   414.0094909667969,
#   193.8159942626953,
#   'damage',
#   11,
#   9,
#   3),
#  (416.37750244140625,
#   184.80799865722656,
#   429.2790832519531,
#   193.8159942626953,
#   'and',
#   11,
#   9,
#   4),
#  (431.6470642089844,
#   184.80799865722656,
#   444.3366394042969,
#   193.8159942626953,
#   '1d4',
#   11,
#   9,
#   5),
#  (446.7046203613281,
#   184.80799865722656,
#   468.1501770019531,
#   193.8159942626953,
#   'points',
#   11,
#   9,
#   6),
#  (470.5181884765625,
#   184.80799865722656,
#   477.2837829589844,
#   193.8159942626953,
#   'of',
#   11,
#   9,
#   7),
#  (479.6517639160156,
#   184.80799865722656,
#   521.3461303710938,
#   193.8159942626953,
#   'Constitution',
#   11,
#   9,
#   8),
#  (321.0,
#   196.80799865722656,
#   351.39837646484375,
#   205.8159942626953,
#   'damage.',
#   11,
#   10,
#   0),
#  (353.766357421875,
#   196.80799865722656,
#   367.1967468261719,
#   205.8159942626953,
#   'This',
#   11,
#   10,
#   1),
#  (369.56475830078125,
#   196.80799865722656,
#   374.8911437988281,
#   205.8159942626953,
#   'is',
#   11,
#   10,
#   2),
#  (377.2591552734375,
#   196.80799865722656,
#   381.25115966796875,
#   205.8159942626953,
#   'a',
#   11,
#   10,
#   3),
#  (383.619140625,
#   196.80799865722656,
#   406.622314453125,
#   205.8159942626953,
#   'poison',
#   11,
#   10,
#   4),
#  (408.99029541015625,
#   196.80799865722656,
#   429.2830810546875,
#   205.8159942626953,
#   'effect',
#   11,
#   10,
#   5),
#  (431.6510925292969,
#   196.80799865722656,
#   444.55267333984375,
#   205.8159942626953,
#   'and',
#   11,
#   10,
#   6),
#  (446.920654296875,
#   196.80799865722656,
#   458.3342590332031,
#   205.8159942626953,
#   'the',
#   11,
#   10,
#   7),
#  (460.7022705078125,
#   196.80799865722656,
#   476.4534606933594,
#   205.8159942626953,
#   'save',
#   11,
#   10,
#   8),
#  (478.82147216796875,
#   196.80799865722656,
#   487.6358642578125,
#   205.8159942626953,
#   'DC',
#   11,
#   10,
#   9),
#  (490.00384521484375,
#   196.80799865722656,
#   495.3310241699219,
#   205.8159942626953,
#   'is',
#   11,
#   10,
#   10),
#  (321.0,
#   208.80799865722656,
#   388.746337890625,
#   217.8159942626953,
#   'Constitution-based.',
#   11,
#   11,
#   0),
#  (312.0,
#   231.77200317382812,
#   356.29437255859375,
#   242.42250061035156,
#   'Aatheriexas',
#   12,
#   0,
#   0),
#  (358.1473693847656,
#   231.77200317382812,
#   375.66925048828125,
#   242.42250061035156,
#   'were',
#   12,
#   0,
#   1),
#  (377.5222473144531,
#   231.77200317382812,
#   394.95489501953125,
#   242.42250061035156,
#   'once',
#   12,
#   0,
#   2),
#  (396.8078918457031,
#   231.77200317382812,
#   400.6753845214844,
#   242.42250061035156,
#   'a',
#   12,
#   0,
#   3),
#  (402.52838134765625,
#   231.77200317382812,
#   417.8428039550781,
#   242.42250061035156,
#   'race',
#   12,
#   0,
#   4),
#  (419.69580078125,
#   231.77200317382812,
#   426.9777526855469,
#   242.42250061035156,
#   'of',
#   12,
#   0,
#   5),
#  (428.83074951171875,
#   231.77200317382812,
#   471.31207275390625,
#   242.42250061035156,
#   'conquerors',
#   12,
#   0,
#   6),
#  (473.1650695800781,
#   231.77200317382812,
#   487.2988586425781,
#   242.42250061035156,
#   'and',
#   12,
#   0,
#   7),
#  (489.15185546875,
#   231.77200317382812,
#   516.6289672851562,
#   242.42250061035156,
#   'slavers,',
#   12,
#   0,
#   8),
#  (518.4819946289062,
#   231.77200317382812,
#   530.9769897460938,
#   242.42250061035156,
#   'but',
#   12,
#   0,
#   9),
#  (312.0,
#   243.77401733398438,
#   331.7182922363281,
#   254.4245147705078,
#   'since',
#   12,
#   1,
#   0),
#  (334.8802795410156,
#   243.77401733398438,
#   347.15936279296875,
#   254.4245147705078,
#   'the',
#   12,
#   1,
#   1),
#  (350.32135009765625,
#   243.77401733398438,
#   395.13671875,
#   254.4245147705078,
#   'destruction',
#   12,
#   1,
#   2),
#  (398.2987060546875,
#   243.77401733398438,
#   405.6656494140625,
#   254.4245147705078,
#   'of',
#   12,
#   1,
#   3),
#  (408.82763671875,
#   243.77401733398438,
#   427.7647705078125,
#   254.4245147705078,
#   'their',
#   12,
#   1,
#   4),
#  (430.9267883300781,
#   243.77401733398438,
#   476.5964660644531,
#   254.4245147705078,
#   'homeworld,',
#   12,
#   1,
#   5),
#  (479.7584533691406,
#   243.77401733398438,
#   492.03839111328125,
#   254.4245147705078,
#   'the',
#   12,
#   1,
#   6),
#  (495.20037841796875,
#   243.77401733398438,
#   531.0235595703125,
#   254.4245147705078,
#   'survivors',
#   12,
#   1,
#   7),
#  (312.0,
#   255.77603149414062,
#   329.1869812011719,
#   266.426513671875,
#   'have',
#   12,
#   2,
#   0),
#  (332.0378723144531,
#   255.77603149414062,
#   369.4217224121094,
#   266.426513671875,
#   'wandered',
#   12,
#   2,
#   1),
#  (372.2734680175781,
#   255.77603149414062,
#   384.55340576171875,
#   266.426513671875,
#   'the',
#   12,
#   2,
#   2),
#  (387.4051513671875,
#   255.77603149414062,
#   417.9558410644531,
#   266.426513671875,
#   'cosmos.',
#   12,
#   2,
#   3),
#  (420.8075866699219,
#   255.77603149414062,
#   467.3935546875,
#   266.426513671875,
#   'Exceedingly',
#   12,
#   2,
#   4),
#  (470.24444580078125,
#   255.77603149414062,
#   492.27728271484375,
#   266.426513671875,
#   'cruel,',
#   12,
#   2,
#   5),
#  (495.1290283203125,
#   255.77603149414062,
#   511.53826904296875,
#   266.426513671875,
#   'they',
#   12,
#   2,
#   6),
#  (514.3890991210938,
#   255.77603149414062,
#   531.0049438476562,
#   266.426513671875,
#   'find',
#   12,
#   2,
#   7),
#  (312.0,
#   267.7780456542969,
#   344.6187744140625,
#   278.42852783203125,
#   'perverse',
#   12,
#   3,
#   0),
#  (350.1097717285156,
#   267.7780456542969,
#   382.57379150390625,
#   278.42852783203125,
#   'pleasure',
#   12,
#   3,
#   1),
#  (388.0647888183594,
#   267.7780456542969,
#   396.1406555175781,
#   278.42852783203125,
#   'in',
#   12,
#   3,
#   2),
#  (401.63165283203125,
#   267.7780456542969,
#   446.1095886230469,
#   278.42852783203125,
#   'tormenting',
#   12,
#   3,
#   3),
#  (451.6006164550781,
#   267.7780456542969,
#   472.3236083984375,
#   278.42852783203125,
#   'those',
#   12,
#   3,
#   4),
#  (477.8146057128906,
#   267.7780456542969,
#   494.2238464355469,
#   278.42852783203125,
#   'they',
#   12,
#   3,
#   5),
#  (499.71484375,
#   267.7780456542969,
#   530.9940795898438,
#   278.42852783203125,
#   'capture,',
#   12,
#   3,
#   6),
#  (312.0,
#   279.7720031738281,
#   333.62567138671875,
#   290.4224853515625,
#   'using',
#   12,
#   4,
#   0),
#  (335.77618408203125,
#   279.7720031738281,
#   355.88543701171875,
#   290.4224853515625,
#   'them',
#   12,
#   4,
#   1),
#  (358.03594970703125,
#   279.7720031738281,
#   365.739501953125,
#   290.4224853515625,
#   'as',
#   12,
#   4,
#   2),
#  (367.8899841308594,
#   279.7720031738281,
#   408.6033020019531,
#   290.4224853515625,
#   'disposable',
#   12,
#   4,
#   3),
#  (410.7537841796875,
#   279.7720031738281,
#   455.99591064453125,
#   290.4224853515625,
#   'bodyguards',
#   12,
#   4,
#   4),
#  (458.1463928222656,
#   279.7720031738281,
#   466.2587890625,
#   290.4224853515625,
#   'or',
#   12,
#   4,
#   5),
#  (468.4093017578125,
#   279.7720031738281,
#   508.7528381347656,
#   290.4224853515625,
#   'subjecting',
#   12,
#   4,
#   6),
#  (510.9033508300781,
#   279.7720031738281,
#   531.0126953125,
#   290.4224853515625,
#   'them',
#   12,
#   4,
#   7),
#  (312.0,
#   291.7740173339844,
#   319.50128173828125,
#   302.42449951171875,
#   'to',
#   12,
#   5,
#   0),
#  (321.7962951660156,
#   291.7740173339844,
#   351.1357421875,
#   302.42449951171875,
#   'sadistic',
#   12,
#   5,
#   1),
#  (353.4307861328125,
#   291.7740173339844,
#   376.83123779296875,
#   302.42449951171875,
#   'magic',
#   12,
#   5,
#   2),
#  (379.12628173828125,
#   291.7740173339844,
#   429.87554931640625,
#   302.42449951171875,
#   'experiments.',
#   12,
#   5,
#   3),
#  (321.0014953613281,
#   303.7760314941406,
#   331.7897033691406,
#   314.426513671875,
#   'An',
#   12,
#   6,
#   0),
#  (336.0821838378906,
#   303.7760314941406,
#   381.2316589355469,
#   314.426513671875,
#   'aatheriexa’s',
#   12,
#   6,
#   1),
#  (385.5241394042969,
#   303.7760314941406,
#   408.87701416015625,
#   314.426513671875,
#   'fleshy',
#   12,
#   6,
#   2),
#  (413.1652526855469,
#   303.7760314941406,
#   431.1844177246094,
#   314.426513671875,
#   'pink',
#   12,
#   6,
#   3),
#  (435.4768981933594,
#   303.7760314941406,
#   459.2505187988281,
#   314.426513671875,
#   'center',
#   12,
#   6,
#   4),
#  (463.5387878417969,
#   303.7760314941406,
#   469.9503479003906,
#   314.426513671875,
#   'is',
#   12,
#   6,
#   5),
#  (474.2428283691406,
#   303.7760314941406,
#   504.3966369628906,
#   314.426513671875,
#   'roughly',
#   12,
#   6,
#   6),
#  (508.6891174316406,
#   303.7760314941406,
#   512.735107421875,
#   314.426513671875,
#   '2',
#   12,
#   6,
#   7),
#  (517.0276489257812,
#   303.7760314941406,
#   531.0263061523438,
#   314.426513671875,
#   'feet',
#   12,
#   6,
#   8),
#  (312.0,
#   315.7780456542969,
#   320.07586669921875,
#   326.42852783203125,
#   'in',
#   12,
#   7,
#   0),
#  (323.62884521484375,
#   315.7780456542969,
#   360.53076171875,
#   326.42852783203125,
#   'diameter,',
#   12,
#   7,
#   1),
#  (364.083740234375,
#   315.7780456542969,
#   378.3875427246094,
#   326.42852783203125,
#   'and',
#   12,
#   7,
#   2),
#  (381.9405212402344,
#   315.7780456542969,
#   412.7283020019531,
#   326.42852783203125,
#   'features',
#   12,
#   7,
#   3),
#  (416.2812805175781,
#   315.7780456542969,
#   420.1487731933594,
#   326.42852783203125,
#   'a',
#   12,
#   7,
#   4),
#  (423.7017822265625,
#   315.7780456542969,
#   441.5560302734375,
#   326.42852783203125,
#   'maw',
#   12,
#   7,
#   5),
#  (445.1090393066406,
#   315.7780456542969,
#   452.4768371582031,
#   326.42852783203125,
#   'of',
#   12,
#   7,
#   6),
#  (456.0298156738281,
#   315.7780456542969,
#   492.24664306640625,
#   326.42852783203125,
#   'gnashing',
#   12,
#   7,
#   7),
#  (495.7996520996094,
#   315.7780456542969,
#   517.5834350585938,
#   326.42852783203125,
#   'teeth.',
#   12,
#   7,
#   8),
#  (521.136474609375,
#   315.7780456542969,
#   530.9973754882812,
#   326.42852783203125,
#   'Its',
#   12,
#   7,
#   9),
#  (312.0,
#   327.7800598144531,
#   346.1717224121094,
#   338.4305419921875,
#   'grasping',
#   12,
#   8,
#   0),
#  (350.48974609375,
#   327.7800598144531,
#   399.913818359375,
#   338.4305419921875,
#   'eye-tentacles',
#   12,
#   8,
#   1),
#  (404.2318115234375,
#   327.7800598144531,
#   423.59820556640625,
#   338.4305419921875,
#   'hang',
#   12,
#   8,
#   2),
#  (427.9162292480469,
#   327.7800598144531,
#   449.0506286621094,
#   338.4305419921875,
#   'down',
#   12,
#   8,
#   3),
#  (453.3686218261719,
#   327.7800598144531,
#   467.8883056640625,
#   338.4305419921875,
#   'like',
#   12,
#   8,
#   4),
#  (472.206298828125,
#   327.7800598144531,
#   484.4862365722656,
#   338.4305419921875,
#   'the',
#   12,
#   8,
#   5),
#  (488.8042297363281,
#   327.7800598144531,
#   511.1532287597656,
#   338.4305419921875,
#   'leaves',
#   12,
#   8,
#   6),
#  (515.4712524414062,
#   327.7800598144531,
#   522.8381958007812,
#   338.4305419921875,
#   'of',
#   12,
#   8,
#   7),
#  (527.15625,
#   327.7800598144531,
#   531.0237426757812,
#   338.4305419921875,
#   'a',
#   12,
#   8,
#   8),
#  (312.0,
#   339.7820739746094,
#   344.0772705078125,
#   350.43255615234375,
#   'weeping',
#   12,
#   9,
#   0),
#  (345.998291015625,
#   339.7820739746094,
#   371.5849914550781,
#   350.43255615234375,
#   'willow',
#   12,
#   9,
#   1),
#  (373.5060119628906,
#   339.7820739746094,
#   387.809814453125,
#   350.43255615234375,
#   'and',
#   12,
#   9,
#   2),
#  (389.7308044433594,
#   339.7820739746094,
#   415.6813049316406,
#   350.43255615234375,
#   'extend',
#   12,
#   9,
#   3),
#  (417.602294921875,
#   339.7820739746094,
#   426.9412536621094,
#   350.43255615234375,
#   'its',
#   12,
#   9,
#   4),
#  (428.86224365234375,
#   339.7820739746094,
#   461.318603515625,
#   350.43255615234375,
#   'effective',
#   12,
#   9,
#   5),
#  (463.2395935058594,
#   339.7820739746094,
#   498.1397399902344,
#   350.43255615234375,
#   'diameter',
#   12,
#   9,
#   6),
#  (500.0607604980469,
#   339.7820739746094,
#   507.56201171875,
#   350.43255615234375,
#   'to',
#   12,
#   9,
#   7),
#  (509.4830017089844,
#   339.7820739746094,
#   512.781005859375,
#   350.43255615234375,
#   '5',
#   12,
#   9,
#   8),
#  (514.7020263671875,
#   339.7820739746094,
#   530.9752807617188,
#   350.43255615234375,
#   'feet.',
#   12,
#   9,
#   9),
#  (312.0,
#   351.7840881347656,
#   357.1452331542969,
#   362.4345703125,
#   'Aatheriexas',
#   12,
#   10,
#   0),
#  (359.4402160644531,
#   351.7840881347656,
#   382.2703857421875,
#   362.4345703125,
#   'weigh',
#   12,
#   10,
#   1),
#  (384.56536865234375,
#   351.7840881347656,
#   439.94378662109375,
#   362.4345703125,
#   'approximately',
#   12,
#   10,
#   2),
#  (442.23876953125,
#   351.7840881347656,
#   454.02569580078125,
#   362.4345703125,
#   '150',
#   12,
#   10,
#   3),
#  (456.3207092285156,
#   351.7840881347656,
#   487.37799072265625,
#   362.4345703125,
#   'pounds.',
#   12,
#   10,
#   4),
#  (517.2501831054688,
#   18.898509979248047,
#   584.0242309570312,
#   40.89850997924805,
#   'Aatheriexa',
#   13,
#   0,
#   0),
#  (561.6531372070312,
#   501.68438720703125,
#   572.3036499023438,
#   541.5391845703125,
#   'Illustration',
#   14,
#   0,
#   0),
#  (561.6531372070312,
#   543.834228515625,
#   572.3036499023438,
#   551.7987670898438,
#   'by',
#   14,
#   0,
#   1),
#  (561.6531372070312,
#   554.09375,
#   572.3036499023438,
#   582.1114501953125,
#   'Damien',
#   14,
#   0,
#   2),
#  (561.6531372070312,
#   584.4064331054688,
#   572.3036499023438,
#   624.146484375,
#   'Mammoliti',
#   14,
#   0,
#   3),
#  (552.8369140625,
#   706.4884643554688,
#   559.0369262695312,
#   728.4884643554688,
#   '7',
#   15,
#   0,
#   0)]

# %%
# x = req_text(92)  # para testar se a função está funcionando
# x
# name_monster = str(req_text(16)[0])
# name_monster

# %% [markdown]
# # Funcao para salvar a imagem com o nome certo

# %%
def img_names_b5 (pg):
    '''Funcao recebe o numero da pagina, roda a função para pegar o nome do monstro. 
    caso o nome do monstro não seja um grupo vzio, tenta rodar a função para pegar a image. Caso a função da imagem de erro, pega a imagem da proxima pagina. e salva na pasta escolhida.
    
    Caso o nome do monstro seja vazio, não tentar pegar mais nada e retorna a menssagem 'Vazio' '''   
    

    if req_text (pg) != []: # if para filtrar quando há nome na pagina
        names = (req_text (pg))    

        for item in names:   # rodando este For para pegar cada item separado quando ha mais de 1 monstro por pagina
            item = str(item)
            name_monster = item
            
        #name_monster = str(req_text(pg)[0])  # funcao req_text para pegar o nome do monstro e tranfomando o nome em str
            try:
                    imagem_pronta = PIL.Image.open(io.BytesIO(req_image(pg)))# abrindo a imagem gerada pela funcao req_image
                
                    imagem_pronta.save('C:/Users/Escanor/Desktop/Iron HAck/Projetos/Projeto obrigatorio/Pathfinder/img_name_b5/'+name_monster+'.jpg')
                
                    print ('imagem salva com o nome de :'+name_monster)
                                              
            except:
                    imagem_pronta = PIL.Image.open(io.BytesIO(req_image(pg+1)))# abrindo a imagem gerada pela funcao req_image
                
                    imagem_pronta.save('C:/Users/Escanor/Desktop/Iron HAck/Projetos/Projeto obrigatorio/Pathfinder/img_name_b5/'+name_monster+'.jpg')
                
                    return 'imagem da proxima pagina salva com o nome de :'+ name_monster

    
    elif req_text (pg) == []: # elif para filtrar quando não ha nome da pagina
        return 'vazio'
        
    
    else: # else para ajudar caso de algum erro em algum lugar estranho. 
        return 'erro'
    
    return 'image(s) Salva'

# %%
for i in range (7,289):
    img_names_b5(i)
# Out:
# imagem salva com o nome de :AATHERIEXA CR 7
# imagem salva com o nome de :OTHAOS CR 5
# imagem salva com o nome de :AERIAL SERVANT CR 11
# imagem salva com o nome de :CERVINAL CR 17
# imagem salva com o nome de :REPTIAL CR 4
# imagem salva com o nome de :AHKHAT CR 4
# imagem salva com o nome de :AHOOL CR 9
# imagem salva com o nome de :AKANAME CR1
# imagem salva com o nome de :AMAROK CR12
# imagem salva com o nome de :AMPHIPTERE CR4
# imagem salva com o nome de :ANDROID CR1
# imagem salva com o nome de :BALISSE CR8
# imagem salva com o nome de :CHORAL CR6
# imagem salva com o nome de :ANIMATEHAIR CR1_2
# imagem salva com o nome de :KNIGHTANT CR4
# imagem salva com o nome de : MEGAPONANT CR6
# imagem salva com o nome de :APALLIE CR2
# imagem salva com o nome de :MEGAPRIMATUS CR8
# imagem salva com o nome de :EXSCINDER CR12
# imagem salva com o nome de :GATEARCHON CR17
# imagem salva com o nome de :GIANTASSASSINBUG CR3
# imagem salva com o nome de : GREATASSASSINBUG CR5
# imagem salva com o nome de :ASTOMOI CR1_2
# imagem salva com o nome de :GANCANAGH CR4
# imagem salva com o nome de :RAELIS CR10
# imagem salva com o nome de :BAGIENNIK CR6
# imagem salva com o nome de :POLARBEAR CR5
# imagem salva com o nome de : DIREPOLARBEAR CR8
# imagem salva com o nome de :BISHAGATSUKU CR9
# imagem salva com o nome de :BLIGHTSPAWN CR5
# imagem salva com o nome de :BRAINMOLE CR1
# imagem salva com o nome de :BRAINMOLEMONARCH CR5
# imagem salva com o nome de :CALLER IN DARKNESS CR 9
# imagem salva com o nome de :CAMEROCERAS CR 11
# imagem salva com o nome de :CAPRAMACE CR 7
# imagem salva com o nome de :BLOOD CATERPILLAR CR 4
# imagem salva com o nome de : HORN CATERPILLAR CR 1
# imagem salva com o nome de :CELEDON CR 1
# imagem salva com o nome de :CERYNITIS CR 7
# imagem salva com o nome de :CETUS CR 13
# imagem salva com o nome de :CHERUFE CR 13
# imagem salva com o nome de :CHUSPIKI CR 2
# imagem salva com o nome de :CLOCKWORK FAMILIAR CR 2
# imagem salva com o nome de :SPHINX COLOSSUS CR 14_
# imagem salva com o nome de :MR 4
# imagem salva com o nome de :WOOD COLOSSUS CR 17_
# imagem salva com o nome de :MR 6
# imagem salva com o nome de :CORPSE LOTUS CR 13
# imagem salva com o nome de :CRONE QUEEN CR 15
# imagem salva com o nome de :CUERO CR 5
# imagem salva com o nome de :CURSED KING CR 10
# imagem salva com o nome de :KABANDHA CR9
# imagem salva com o nome de :CYTILLIPEDE CR6
# imagem salva com o nome de :CALIGNI CR1_2
# imagem salva com o nome de :DEATHCOACH CR14
# imagem salva com o nome de :DEEPONE CR1
# imagem salva com o nome de :ELDERDEEPONE CR14
# imagem salva com o nome de :DEEPONEHYBRID CR1_2
# imagem salva com o nome de :DELGETH CR6
# imagem salva com o nome de :GRISTLYDEMODAND CR17
# imagem salva com o nome de :STRINGYDEMODAND CR15
# imagem salva com o nome de :ABRIKANDILU CR3
# imagem salva com o nome de :CAMBION CR2
# imagem salva com o nome de :SERAPTIS CR15
# imagem salva com o nome de :DEVASTATOR CR22_
# imagem salva com o nome de :MR8
# imagem salva com o nome de :HERESY DEVIL (AYNGAVHAUL) CR 12
# imagem salva com o nome de :WARMONGER DEVIL (LEVALOCH) CR 7
# imagem salva com o nome de :DIGMAUL CR 3
# imagem salva com o nome de :CERATOSAURUS CR 5
# imagem salva com o nome de : PLESIOSAURUS CR 2
# imagem salva com o nome de :TROODON CR 1
# imagem salva com o nome de : THERIZINOSAURUS CR 10
# imagem salva com o nome de :DOPPELDREK CR 5
# imagem salva com o nome de :DRAGONKIN CR 9
# imagem salva com o nome de :ETHER DRAKE CR 10
# imagem salva com o nome de :JUNGLE DRAKE CR 6
# imagem salva com o nome de :DUPPY CR 7
# imagem salva com o nome de :DWIERGETH CR 13
# imagem salva com o nome de :ECHENEIS CR 1
# imagem salva com o nome de :ENCANTADO CR 8
# imagem salva com o nome de :ETIAINEN CR 1
# imagem salva com o nome de :FASTACHEE CR11
# imagem salva com o nome de :FEXT CR10
# imagem salva com o nome de :FIRBOLG CR4
# imagem salva com o nome de :FROGFATHER CR5
# imagem salva com o nome de : GOLIATHFROG CR3
# imagem salva com o nome de :GEGENEES CR16
# imagem salva com o nome de :GHORAN CR1
# imagem salva com o nome de :LENGGHOUL CR10
# imagem salva com o nome de :ECLIPSEGIANT CR19
# imagem salva com o nome de :MOONGIANT CR15
# imagem salva com o nome de :SUNGIANT CR16
# imagem salva com o nome de :CRYSTALGOLEM CR11
# imagem salva com o nome de :LEADGOLEM CR10
# imagem salva com o nome de :GRAVEBOUND CR4
# imagem salva com o nome de :GRAY CR4
# imagem salva com o nome de :GRAYGOO CR14
# imagem salva com o nome de :HOBKINS CR1_2
# imagem salva com o nome de :NUNO CR1_4
# imagem salva com o nome de :GRIEFGALL CR6
# imagem salva com o nome de :GRIMSLAKE CR6
# imagem salva com o nome de :GRIOTH CR1
# imagem salva com o nome de :GUARDIANSCROLL CR3
# imagem salva com o nome de :GUNPOWDEROOZE CR14
# imagem salva com o nome de :HAGEYEOOZE CR3
# imagem salva com o nome de :HEIKEGANI CR4
# imagem salva com o nome de :ICHTHYOCENTAUR CR5
# imagem salva com o nome de :ISONADE CR15
# imagem salva com o nome de :KARKADANN CR4
# imagem salva com o nome de :KAWAAKAGO CR3
# imagem salva com o nome de :KETESTHIUS CR13
# imagem salva com o nome de :KHALA CR17
# imagem salva com o nome de :KIKIMORA CR5
# imagem salva com o nome de :KUROBOZU CR6
# imagem salva com o nome de :LAMHIGYN CR3
# imagem salva com o nome de :LEECHROOT CR4
# imagem salva com o nome de :FLYTRAPLESHY CR4
# imagem salva com o nome de :LOTUSLESHY CR5
# imagem salva com o nome de :LIMINALSPRITE CR2
# imagem salva com o nome de :LIVINGMIRAGE CR9
# imagem salva com o nome de :LOTUS TREE CR 20
# imagem salva com o nome de :MANU CR 12
# imagem salva com o nome de :RISHI MANU CR 14
# imagem salva com o nome de :CHALICOTHERIUM CR 6
# imagem salva com o nome de : KAPROSUCHUS CR 5
# imagem salva com o nome de :MOA CR 2
# imagem salva com o nome de : UINTATHERIUM CR 7
# imagem salva com o nome de :DEEP MERFOLK CR 3
# imagem salva com o nome de :MNGWA CR 7
# imagem salva com o nome de :MOON DOG CR 9
# imagem salva com o nome de :MUCKDWELLER CR 1_4
# imagem salva com o nome de : GIANT MUCKDWELLER CR 2
# imagem salva com o nome de :SWAMP MUMMY CR 4
# imagem salva com o nome de :MUSE CR 16
# imagem salva com o nome de :NEMHAIN CR 15
# imagem salva com o nome de :NINGEN CR 16
# imagem salva com o nome de :NULMIND CR 11
# imagem salva com o nome de :OPHIOTAURUS CR 17_
# imagem salva com o nome de :MR 7
# imagem salva com o nome de :ORANG-PENDAK CR 1_2
# imagem salva com o nome de :OSTOVITE CR 1
# imagem salva com o nome de :PAPINIJUWARI CR 13
# imagem salva com o nome de :PEUCHEN CR 10
# imagem salva com o nome de :UNFETTERED PHANTOM CR 4
# imagem salva com o nome de :PHARAONIC GUARDIAN CR 11
# imagem salva com o nome de :PLAGUED HORSE CR 2
# imagem salva com o nome de :PLANKTA CR 17
# imagem salva com o nome de :POLONG CR 8
# imagem salva com o nome de :PSYCHEMENTAL CR 8
# imagem salva com o nome de :PSYCHEPORE CR 7
# imagem salva com o nome de :PUTRID OOZE CR 11
# imagem salva com o nome de :PYRAUSTA CR 1_4
# imagem salva com o nome de :RAMIDREJU CR 1_2
# imagem salva com o nome de :REPTOID CR 1_2
# imagem salva com o nome de :RHU-CHALIK CR 6
# imagem salva com o nome de :RIFTCREEPER CR 15
# imagem salva com o nome de :ANNIHILATOR CR 16
# imagem salva com o nome de :GEARSMAN CR 4
# imagem salva com o nome de :MYRMIDON CR11
# imagem salva com o nome de :TERRAFORMER CR7
# imagem salva com o nome de :ROILINGOIL CR6
# imagem salva com o nome de :ROPEDRAGON CR5
# imagem salva com o nome de :ESIPIL CR2
# imagem salva com o nome de :PAKALCHI CR9
# imagem salva com o nome de :QOLOK CR16
# imagem salva com o nome de :WIHSAAK CR6
# imagem salva com o nome de :SANGOI CR7
# imagem salva com o nome de :SAXRA CR18
# imagem salva com o nome de :SCARABSWARM CR3
# imagem salva com o nome de : SCARAB,GIANT CR6
# imagem salva com o nome de :SCITALIS CR12
# imagem salva com o nome de :HUNTERURCHIN CR1
# imagem salva com o nome de : SPEARURCHIN CR4
# imagem salva com o nome de :SHA CR4
# imagem salva com o nome de :SHABTI CR1_2
# imagem salva com o nome de :SHADOWCOLLECTOR CR8
# imagem salva com o nome de :SHASALQU CR3
# imagem salva com o nome de :GIANTMANTISSHRIMP CR9
# imagem salva com o nome de :SKINWALKER CR1_2
# imagem salva com o nome de :SOMALCYGOT CR12
# imagem salva com o nome de :STORMHAG CR7
# imagem salva com o nome de :STORMGHOST CR15
# imagem salva com o nome de :STRANGLEREED CR9
# imagem salva com o nome de :SU CR8
# imagem salva com o nome de :SYRICTA CR12
# imagem salva com o nome de :GIANT TERMITE CR 3
# imagem salva com o nome de : TERMITE SWARM CR 6
# imagem salva com o nome de :THOUGHT EATER CR 2
# imagem salva com o nome de :THRIAE CONSTRUCTOR CR 14
# imagem salva com o nome de :THRIAE DANCER CR 6
# imagem salva com o nome de :TIYANAK CR 6
# imagem salva com o nome de :TIZHERUK CR 5
# imagem salva com o nome de :TRENCH MIST CR 10
# imagem salva com o nome de :TSAALGREND CR 2
# imagem salva com o nome de :UNDIGESTED CR1_4
# imagem salva com o nome de : UNDIGESTEDSWARM CR5
# imagem salva com o nome de :URAEUS CR5
# imagem salva com o nome de :URANNAG CR8
# imagem salva com o nome de :URSIKKA CR10
# imagem salva com o nome de :MAKARAVAHANA CR9
# imagem salva com o nome de :VED CR5
# imagem salva com o nome de :VESCAVORQUEEN CR9
# imagem salva com o nome de :VESCAVORSWARM CR5
# imagem salva com o nome de :VUKODLAK CR3
# imagem salva com o nome de :WAKANDAGI CR14
# imagem salva com o nome de :WARMONGERWASP CR7
# imagem salva com o nome de :WATERLEAPER CR2
# imagem salva com o nome de :NARWHAL CR3
# imagem salva com o nome de : BLUEWHALE CR12
# imagem salva com o nome de :WITCHCROW CR3
# imagem salva com o nome de :WIZARD’SSHACKLE CR1_2
# imagem salva com o nome de :WOLLIPED CR3
# imagem salva com o nome de :FIREWYSP CR2
# imagem salva com o nome de :XIAO CR2
# imagem salva com o nome de :YANGETHE CR9

# %%
#  page_text = doc[92]  # salvando a pagina [numero da pagina] como page_text 
#  words = page_text.get_text("words")
